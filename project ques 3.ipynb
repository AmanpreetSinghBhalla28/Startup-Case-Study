# %% [markdown]
# # Importing libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
pwd
# Out:
# 'C:\\Users\\Aman Bhalla\\Documents\\Codig Ninja project'

# %% [markdown]
# # Loading pandas data frame using using panda library

# %%
df = pd.read_csv(r'C:\\Users\\Aman Bhalla\\Documents\\Codig Ninja project\\startup_funding.csv' , encoding ='utf-8')
df
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 3                            DIY Ecommerce platform       Mumbai
# 4                     healthcare service aggregator    Hyderabad
# ...                                             ...          ...
# 2367                                            NaN          NaN
# 2368                                            NaN          NaN
# 2369                                            NaN          NaN
# 2370                                            NaN          NaN
# 2371                                            NaN          NaN
#
#                                           InvestorsName  InvestmentType  \
# 0                                           Kae Capital  Private Equity
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                        Narottam Thudi, Shireesh Palle    Seed Funding
# ...                                                 ...             ...
# 2367                        Asia Pacific Internet Group  Private Equity
# 2368                                     KARSEMVEN Fund  Private Equity
# 2369                     Exfinity Fund, GrowX Ventures.  Private Equity
# 2370                                         MakeMyTrip  Private Equity
# 2371                  UK based Group of Angel Investors    Seed Funding
#
#      AmountInUSD                            Remarks
# 0      1,300,000                                NaN
# 1            NaN                                NaN
# 2            NaN                                NaN
# 3        500,000                                NaN
# 4        850,000                                NaN
# ...          ...                                ...
# 2367   4,500,000                                NaN
# 2368     825,000                Govt backed VC Fund
# 2369   1,500,000                                NaN
# 2370         NaN  Strategic Funding, Minority stake
# 2371     140,000                                NaN
#
# [2372 rows x 10 columns]

# %% [markdown]
# ##  Taking investor name and startupname columns from data frame into new Data Frame

# %%
df = df[['InvestorsName','StartupName']]
df.dropna(inplace=True)# dropping nan values from Data Frame
df
# Out:
# C:\Users\Aman Bhalla\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                           InvestorsName       StartupName
# 0                                           Kae Capital          TouchKin
# 1                            Triton Investment Advisors           Ethinos
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...      Leverage Edu
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...              Zepo
# 4                        Narottam Thudi, Shireesh Palle      Click2Clinic
# ...                                                 ...               ...
# 2367                        Asia Pacific Internet Group        Printvenue
# 2368                                     KARSEMVEN Fund          Graphene
# 2369                     Exfinity Fund, GrowX Ventures.    Mad Street Den
# 2370                                         MakeMyTrip         Simplotel
# 2371                  UK based Group of Angel Investors  couponmachine.in
#
# [2364 rows x 2 columns]

# %% [markdown]
# # Correcting spell errors in Startup Columns of the Data Frame

# %% [markdown]
# Converting all the strings in startup column to lower alphabet
# Finding wrong spellings of major startup such as flipkart,oyo,ola and paytym
# replacing incorrect values of the these start up in the Data Frame

# %%
df['StartupName'] = df['StartupName'].str.lower()
df['StartupName'].replace(['flipkart.com','flipkart'],'flipkart',inplace=True)
df['StartupName'].replace(['oyo rooms','oyorooms','oyo'],'oyo',inplace=True)
df['StartupName'].replace(['ola','ola cabs'],'ola',inplace=True)
df['StartupName'].replace(['paytm marketplace','paytm'],'paytm',inplace=True)
df
# Out:
# C:\Users\Aman Bhalla\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Aman Bhalla\anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#                                           InvestorsName       StartupName
# 0                                           Kae Capital          touchkin
# 1                            Triton Investment Advisors           ethinos
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...      leverage edu
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...              zepo
# 4                        Narottam Thudi, Shireesh Palle      click2clinic
# ...                                                 ...               ...
# 2367                        Asia Pacific Internet Group        printvenue
# 2368                                     KARSEMVEN Fund          graphene
# 2369                     Exfinity Fund, GrowX Ventures.    mad street den
# 2370                                         MakeMyTrip         simplotel
# 2371                  UK based Group of Angel Investors  couponmachine.in
#
# [2364 rows x 2 columns]

# %% [markdown]
# #  Splitting the (, ) separated investors in Data Frame to new Data Frame

# %%
arr = df['InvestorsName'].str.split(',',expand=True)
arr.columns =['c0','c1','c2','c3','c4','c5','c6','c7','c8','c9']
arr
# Out:
#                                      c0                 c1              c2  \
# 0                           Kae Capital               None            None
# 1            Triton Investment Advisors               None            None
# 2                        Kashyap Deorah   Anand Sankeshwar     Deepak Jain
# 3                            Kunal Shah        LetsVenture   Anupam Mittal
# 4                        Narottam Thudi     Shireesh Palle            None
# ...                                 ...                ...             ...
# 2367        Asia Pacific Internet Group               None            None
# 2368                     KARSEMVEN Fund               None            None
# 2369                      Exfinity Fund    GrowX Ventures.            None
# 2370                         MakeMyTrip               None            None
# 2371  UK based Group of Angel Investors               None            None
#
#                  c3            c4            c5              c6    c7    c8  \
# 0              None          None          None            None  None  None
# 1              None          None          None            None  None  None
# 2      Sadashiva NT   Arjun Mehta   Satish Kaul   Anindya Ghose  None  None
# 3      Hetal Sonpal          None          None            None  None  None
# 4              None          None          None            None  None  None
# ...             ...           ...           ...             ...   ...   ...
# 2367           None          None          None            None  None  None
# 2368           None          None          None            None  None  None
# 2369           None          None          None            None  None  None
# 2370           None          None          None            None  None  None
# 2371           None          None          None            None  None  None
#
#         c9
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 2367  None
# 2368  None
# 2369  None
# 2370  None
# 2371  None
#
# [2364 rows x 10 columns]

# %% [markdown]
# # Adding Startup Column name to the new Data Frame

# %%
arr['StartupName'] = df['StartupName']
arr
# Out:
#                                      c0                 c1              c2  \
# 0                           Kae Capital               None            None
# 1            Triton Investment Advisors               None            None
# 2                        Kashyap Deorah   Anand Sankeshwar     Deepak Jain
# 3                            Kunal Shah        LetsVenture   Anupam Mittal
# 4                        Narottam Thudi     Shireesh Palle            None
# ...                                 ...                ...             ...
# 2367        Asia Pacific Internet Group               None            None
# 2368                     KARSEMVEN Fund               None            None
# 2369                      Exfinity Fund    GrowX Ventures.            None
# 2370                         MakeMyTrip               None            None
# 2371  UK based Group of Angel Investors               None            None
#
#                  c3            c4            c5              c6    c7    c8  \
# 0              None          None          None            None  None  None
# 1              None          None          None            None  None  None
# 2      Sadashiva NT   Arjun Mehta   Satish Kaul   Anindya Ghose  None  None
# 3      Hetal Sonpal          None          None            None  None  None
# 4              None          None          None            None  None  None
# ...             ...           ...           ...             ...   ...   ...
# 2367           None          None          None            None  None  None
# 2368           None          None          None            None  None  None
# 2369           None          None          None            None  None  None
# 2370           None          None          None            None  None  None
# 2371           None          None          None            None  None  None
#
#         c9       StartupName
# 0     None          touchkin
# 1     None           ethinos
# 2     None      leverage edu
# 3     None              zepo
# 4     None      click2clinic
# ...    ...               ...
# 2367  None        printvenue
# 2368  None          graphene
# 2369  None    mad street den
# 2370  None         simplotel
# 2371  None  couponmachine.in
#
# [2364 rows x 11 columns]

# %%
#getting unique startupname values from the data frame
arr2 = arr['StartupName'].unique()
arr2
# Out:
# array(['touchkin', 'ethinos', 'leverage edu', ..., 'graphene',
#        'simplotel', 'couponmachine.in'], dtype=object)

# %%
#grouping by according to startup name
df1 = arr.groupby('StartupName')

# %% [markdown]
# # Getting Unique investors  of Every Startup

# %% [markdown]
# Getting unique values from the arr2 and generating the df for each particular Startup
# Stripping the values From the each startup and strip them , then adding them into set so only unique investors are collected for a particular startup

# %%
# Creating an list l
l = []

for key in range(len(arr2)):
    df2 = df1.get_group(arr2[key])
    s = set()
    for i in range(len(df2)):
        for j in range(len(df2.columns)):
            if(type(df2.iloc[i,j])==str ):
                s.add(df2.iloc[i,j].strip())#ading values into set
                t = list(s) # converting set to list
    l.append(t)   #appending each list into another list list l 
l
# Out:
# [['Amit Gupta',
#   'Himanshu Aggarwal',
#   'Raghunandan G',
#   'Anuj Srivastava',
#   'touchkin',
#   'Alok Mittal',
#   'Kae Capital',
#   'Puneet Agarwal'],
#  ['ethinos', 'Triton Investment Advisors'],
#  ['Sadashiva NT',
#   'Deepak Jain',
#   'Kashyap Deorah',
#   'Arjun Mehta',
#   'Anindya Ghose',
#   'Anand Sankeshwar',
#   'Satish Kaul',
#   'leverage edu'],
#  ['LetsVenture', 'Kunal Shah', 'Anupam Mittal', 'Hetal Sonpal', 'zepo'],
#  ['click2clinic', 'Narottam Thudi', 'Shireesh Palle'],
#  ['billion loans', 'Reliance Corporate Advisory Services Ltd'],
#  ['ecolibriumenergy', 'Infuse Ventures', 'JLL'],
#  ['droom',
#   'Lightbox',
#   'Digital Garage Inc',
#   'Beenext',
#   'Digital Garage',
#   'Beenos',
#   'Asset Management (Asia) Ltd'],
#  ['Nexus India Capital Advisors', 'Kalaari Capital', 'jumbotail'],
#  ['Jungle Ventures',
#   'Accel Partner',
#   'Accel Partners',
#   'Rocketship',
#   'Shailesh Rao',
#   'International Finance Corporation',
#   'moglix',
#   'Ratan Tata',
#   'SeedPlus',
#   'Venture Highway'],
#  ['Unilazer Ventures', 'timesaverz', 'BCCL'],
#  ['Contrarian Capital India Partners',
#   'Sirion Labs',
#   'Pallav Nadhani',
#   'Emergent Ventures India',
#   'Ashish Gupta',
#   'minjar',
#   'Blume Ventures',
#   'Sharad Sharma'],
#  ['clip app', 'India Quotient', 'Shunwei Capital'],
#  ['Sreeram Iyer',
#   'Likemind Ventures',
#   'upwardly.in',
#   'Suvo Sarkar',
#   'Anita Gupta'],
#  ['Mitsui & Co.', 'autorox.co'],
#  ['fabogo', 'Dunamis Ventures Pte Ltd'],
#  ['Sourav Ganguly',
#   'Moksh Sports Ventures',
#   'flickstree',
#   'Ankit Aditya',
#   'Venture Catalysts'],
#  ['Sidharth Pansari',
#   'Apurva Salarpuria',
#   'Sprout Capital',
#   'design cafe',
#   'Fireside Ventures'],
#  ['Catamaran Ventures',
#   'New India Investment Corporation',
#   'SBI-FMO Fund',
#   'innoviti',
#   'Bessemer Venture Partners'],
#  ['MAPE Advisory Group', 'vdeliver', 'Corvus Ventures'],
#  ['Rajan Anandan',
#   'Purvi Capital',
#   'Abhishek Gupta',
#   'bottr.me',
#   '500 Startups'],
#  ['arcatron', 'Indian Angel Network'],
#  ['Brigade Innovations LLP',
#   'qwikspec',
#   'Bobby Reddy',
#   'TV Mohandas Pai',
#   'Suhail Rahman',
#   'M George Oommen',
#   'Undisclosed Investors'],
#  ['chumbak', 'Blacksoil Capital Pvt. Ltd'],
#  ['Anshuman Das',
#   'Grey Orange',
#   'Rishi Das',
#   'Sequoia Capital',
#   'Rajesh Ramaiah',
#   'increff'],
#  ['vayana', 'Jungle Ventures', 'IDG Ventures India Advisors'],
#  ['mobiquest', 'One97 Communication Ltd'],
#  ['ambee', 'Amaya Capital LLP', 'Uber Technologies Inc'],
#  ['Xelpmoc', 'ideal insurance'],
#  ['hypernova interactive', 'Kae Capital'],
#  ['rentomojo',
#   'Accel Partners India',
#   'Renaud Laplanche',
#   'ain Capital Ventures',
#   'IDG Ventures India'],
#  ['aircto', 'Francesco Cara'],
#  ['ABI-Showatech (India) Ltd', 'playablo'],
#  ['', 'trupay', 'M&S Partners', 'Kae Capital'],
#  ['Mayank Mittal & Others',
#   'Sundeep Sahni',
#   'brick2wall',
#   'Subramani Somasundaram'],
#  ['Fusiontech Ventures & Others', 'Harmeet Bajaj', 'fablestreet', 'Pameela P'],
#  ['Rajan Anandan',
#   'monsoon fintech',
#   'Aditya Singh',
#   'Sunil Kalra',
#   'Rishi Srivastava'],
#  ['NB Ventures',
#   'Nspira',
#   'monkeybox',
#   'Blume Ventures & Others',
#   'Blume Ventures'],
#  ['', 'noticeboard', 'Stellaris Venture Partners'],
#  ['byju’s',
#   'Lightspeed Ventures',
#   'Sofina',
#   'Sequoia India',
#   'International Financial Corporation',
#   'Tencent Holdings',
#   'Sequoia Capital',
#   'Verlinvest',
#   'Chan Zuckerberg Initiative',
#   'Times Internet Ltd'],
#  ['Yuvraj Singh', 'creator’s gurukul'],
#  ['fab hotels', 'Goldman Sachs'],
#  ['thinkerbell', 'Anand Mahindra', 'Indian Angel Network'],
#  ['Maverick Capital Ventures',
#   'Omidyar Network and Kae Capital',
#   'Sequoia India',
#   'Sequoia Capital',
#   'Omidyar Network',
#   'HBM Healthcare Investments',
#   '1mg'],
#  ['Anjani Prasad',
#   'Malini Patel',
#   'Stelcore Management Services',
#   'jhakaas',
#   'Amen Dhyllon'],
#  ['Info Edge (India) Ltd', 'bigstylist'],
#  ['gympik.com', 'RoundGlass Partners'],
#  ['Grace Grace Techno Ventures LLP',
#   'Rajul Garg & Other undisclosed investors',
#   'tripeur'],
#  ['rentongo',
#   'Kalpana Tatavarti',
#   'Shivanandan Pare',
#   'Anand Chandrasekaran',
#   'TVS Motor Company',
#   'Rajesh Sawhney'],
#  ['goomo', 'Emerging India'],
#  ['maxmywealth', 'blockchain ecosystem Global Advisors', 'Horseferry'],
#  ['Sandeep Tandon',
#   'Kunal Shah',
#   'spinny',
#   'Blume Ventures',
#   'Indian Angel Network'],
#  ['healthbuds', 'Bharat Kedia', 'Arun Patodia'],
#  ['500 Startups', 'IvyCap Ventures', 'ftcash'],
#  ['Blume Ventures', 'bhive workspace'],
#  ['Harsh Mahajan', 'Sreepathy Viswanathan', 'wayforward', 'Farhan Naqvi'],
#  ['Harvard Angels',
#   'gyandhan',
#   'Sundaram Finance Holdings',
#   'Stanford Angels & Entrepreneurs'],
#  ['SBI (Stand Up India Scheme)', 'hungry foal'],
#  ['GrowX Ventures',
#   'WaterBridge Ventures',
#   'Arun Venkatachalam',
#   'Badal Malick',
#   'Sunil Kalra',
#   'ziploan'],
#  ['growfitter', 'SQue Capital'],
#  ['Bodhtree Consulting Limited', 'stratfit'],
#  ['multiplier solutions', 'Norwest Venture Partners'],
#  ['Norwest Venture Partners', 'abi health'],
#  ['Mohan Alexander',
#   'Vikrant Varshney',
#   'R. Natarajan',
#   'Amit Sinha',
#   'stockal',
#   'R Natarajan'],
#  ['Nirmal Singh',
#   'Abhai S. Rao',
#   'Nick Haulkoury',
#   'Pawan Borle',
#   'Manish Prasad',
#   'guidoo',
#   'Vineet Varma'],
#  ['Dr Ramesh Ayyala', 'esahai.in', 'Satya Muthyala'],
#  ['', 'Huang Wei', 'loanmeet', 'Cao Yibin', 'Madhusudan E'],
#  ['Mayfield India',
#   'Bertelsmann India Investments',
#   'Mayfield',
#   'Anicut Capital',
#   'Shailesh Mehta',
#   'Yes Bank',
#   'lendingkart',
#   'Ashvin Chadha',
#   'India Quotient',
#   'Saama Capital'],
#  ['Suresh Shankar',
#   'Unicorn India Ventures',
#   'Vivek Bhargava',
#   'boxx.ai',
#   'Venky Krishnakumar'],
#  ['Green Shots Capital',
#   'peesafe.in',
#   'Real Time Ventures',
#   'Venture Catalysts',
#   'Alfa Capital'],
#  ['vista rooms',
#   'Rajan Anandan',
#   'Girish Mathrubootham',
#   'Singularity Holdings',
#   'Artha India Ventures'],
#  ['Transamerica',
#   'coverfox',
#   'SAIF Partners.',
#   'Accel India',
#   'Accel US',
#   'Cataraman Ventures'],
#  ['Founders Fund', 'Nexus Venture Partners', 'hypertrack'],
#  ['goodera', 'Omidyar Network', 'Nexus Venture Partners'],
#  ['digit', 'Fairfax Holdings'],
#  ['SIMI Pacific Pte',
#   'SoftBank Group Corp',
#   'Capital Advisers',
#   'Falcon Edge Capital',
#   'ola',
#   'SoftBank Group',
#   'NY based Hedge Fund',
#   'Didi Kuaidi',
#   'Tiger Global',
#   'Ratan Tata',
#   'Baillie Gifford',
#   'Softbank',
#   'Tekne Capital Management LLC',
#   'DST Global'],
#  ['vanitycask', 'RB Investments'],
#  ['undisclosed investors', 'mrneeds'],
#  ['Prime Venture Partners', 'NEA', 'moneytap', 'Sequoia India'],
#  ['Manipal Group', 'Mekin Maheshwari', 'Nexus Venture Partners', 'goodbox'],
#  ['Mohammed Khan', 'fincash', 'Sameer Narayan & Others'],
#  ['portdesk', 'Alphard Maritime Group'],
#  ['Rajasthan Angel Innovators Network',
#   'The Chennai Angels',
#   'edgefx',
#   'Cross Border Angels & Experts'],
#  ['Saama Capital',
#   'eazydiner',
#   'Gulpreet Kohli',
#   'Deepak Shahdadpuri',
#   'YouWeCan Ventures',
#   'DSG Consumer Partners'],
#  ['healthintel', 'BLIP Initiatives'],
#  ['Inventus Capital',
#   'IDG Ventures',
#   'Eight Roads Ventures',
#   'unbxd',
#   'Indian Angel Network'],
#  ['Lightspeed India Partners',
#   'Startupxseed Ventures LLP',
#   'Aaruha Technology Fund',
#   '3one4 Capital Advisors LLP',
#   '3one4 Capital',
#   'darwinbox',
#   'Tracxn Labs',
#   'Endiya Partners'],
#  ['forevershop', '91maker.com'],
#  ['insider.in', 'Paytm'],
#  ['Axis Capital',
#   'Rocketship',
#   'GrowX',
#   'FJ Labs',
#   'fynd',
#   'IIFL Seed Ventures',
#   'Kae Capital',
#   'Tracxn Labs',
#   'Venture Catalysts',
#   'Singularity Ventures'],
#  ['grow fit',
#   'SAR Group',
#   'Manipal Education and Medical Group (MEMG)',
#   'The Grover Trust'],
#  ['iBhubs', 'fabulyst'],
#  ['UC-RNT Fund',
#   'Falcon Edge Capital',
#   'Meru Capital',
#   'mswipe',
#   'Axis Bank',
#   'alcon Edge Capital',
#   'DSG Consumer Partners',
#   'Ola',
#   'Matrix Partners'],
#  ['Sequoia Capital', 'oneassist', 'Lightspeed Ventures'],
#  ['Gordon and Betty Moore Foundation',
#   'General Catalyst',
#   'Founder Collective',
#   'julia computing'],
#  ['kissht', 'Ventureast', 'Endiya Partners'],
#  ['Mekin Maheshwari',
#   'explore life traveling',
#   'Krish Seshadri',
#   'Amar Arsikere',
#   'Bharat Vijay'],
#  ['loantap',
#   'and MAS Financial Services Ltd',
#   'Jaysukh Sapra',
#   'India Quotient',
#   'Kae Capital',
#   'Dr. Abhishek Pandey',
#   'IFMR'],
#  ['voxweb',
#   'Undisclosed Investor',
#   'Jitendra Gupta & others',
#   'Undisclosed investors'],
#  ['Rajeev Menon',
#   'hug innovations',
#   'Mohit Srivastav',
#   'Kishore Ganji',
#   'Venkat Vallabhaneni'],
#  ['eBay',
#   'Coleman and Co. Ltd (BCCL)',
#   'Bennett',
#   'Steadview Capital and existing investors',
#   'Tencent Holdings',
#   'Morgan Stanley',
#   'Naspers',
#   'flipkart',
#   'Microsoft'],
#  ['Seedfund', 'v resorts', 'RB International'],
#  ['Snow Leopard Ventures', 'Alto Partners', 'stashfin'],
#  ['formcept', 'Gujarat Venture Finance Ltd'],
#  ['spares hub',
#   'Inc95 Consulting',
#   'Esvee Technologies Inc',
#   'Anthill Scale Ventures',
#   'The Chennai Angels'],
#  ['Aparup Sengupta', '', 'Devendra Reddy', 'fitraq'],
#  ['Udayan Goyal', 'rubique', 'Kalaari Capital'],
#  ['niki.ai', 'SAP', 'Ratan Tata', 'Unilazer Ventures', 'SAP.iO'],
#  ['Gaurav Marya', 'fitpass', 'Mumbai Angels', 'Abhinav Bindra'],
#  ['Zeta', 'zinghr'],
#  ['tagos design', 'Undisclosed Investors'],
#  ['urbanclap',
#   'Accel Partner',
#   'Accel Partners',
#   'Kunal Bahl',
#   'Bessemer Venture Partner',
#   'Accel',
#   'Vy Capital',
#   'Trifecta Capital',
#   'Ratan Tata',
#   'Rohit Bansal',
#   'Bessemer Venture Partners',
#   'SAIF Partners'],
#  ['Clairvest Group', 'ace2three'],
#  ['Nandan Nilekani',
#   'Accel Partners',
#   'International Finance Corporation',
#   'power2sme',
#   'Kalaari Capital and Inventus Capital'],
#  ['Hyderabad Angels', 'innovapptive'],
#  ['', '4tigo', 'Nandan Nilekani', 'Accel Partners'],
#  ['smecorner', 'Dutch government fund'],
#  ['zippserve', 'undisclosed investors'],
#  ['sumeru', 'undisclosed investors'],
#  ['BEENEXT',
#   'healthians',
#   'Beenext',
#   'Asuka Holdings',
#   'Beenos',
#   'YouWeCan Ventures',
#   'M&S Partners'],
#  ['healthmir', 'Nimit Panigrahi'],
#  ['uactive', 'Hinduja family'],
#  ['50K Ventures', 'i-lend'],
#  ['good methods global', 'Accel Partners'],
#  ['balance app', 'Rainmatter'],
#  ['Helion Venture Partners',
#   'Rainbow Digital Services Pvt. Ltd',
#   'ILearnFinance Academy Pvt. Ltd.',
#   'yepme',
#   'JS Capital',
#   'Capricorn Investment Group',
#   'Khazanah Nasional Berhad',
#   'Gokaldas Exports Ltd'],
#  ['Shailesh Singh',
#   'LetsVenture',
#   'nightstay',
#   'BedRock Ventures',
#   'Indian Angels Network',
#   'Rajesh Sawhney'],
#  ['devourin', 'Deepak Nathani'],
#  ['LetsVenture', 'mygreens', 'Ajay Relan'],
#  ['C31 Ventures', 'Vertex Ventures', 'ace turtle'],
#  ['IDG Ventures',
#   'Accel Partners',
#   'Ruchi Sanghvi & others',
#   'Gokul Rajaram',
#   'Kalaari Capital',
#   'curefit',
#   'RNT Capital',
#   'Aditya Agarwal'],
#  ['Satoshi Studios', 'curie labs'],
#  ['Anand Chandrasekaran', 'uncanny vision'],
#  ['anchanto', 'Luxasia Group'],
#  ['sequretek', 'GVFL', 'Unicorn India Ventures'],
#  ['Amit Ranjan',
#   'Rajan Anandan',
#   'Salil Donde',
#   'Govind Rajan & Others',
#   'lucideus',
#   'Amit Choudhary',
#   'Vellayan Subbiah',
#   'Rahul Chawla',
#   'Jonathan Boutelle'],
#  ['vidooly', 'GVFL', 'Bessemer Venture Partners', 'Times Internet'],
#  ['Tiger Global & Other investors',
#   'Tiger Global Management',
#   'GIC',
#   'shopclues',
#   'InnoVen Capital',
#   'Nexus Venture Partners'],
#  ['1Crowd', 'fourth ambit'],
#  ['Varsha Rao', 'Surojit Chatterjee', 'Nirav Choksi & Others', 'chymera vr'],
#  ['Dewan Housing Finance Corp', 'DG Ventures India', 'early salary'],
#  ['Chirag Nikunj Sheth & Others', 'book my diamond'],
#  ['Aakrit Vaish', 'Swapan Rajdev', 'ion energy', 'Sushill Jiwarajka'],
#  ['legal raasta', 'Impanix Capital'],
#  ['GEMs', 'log 9 materials'],
#  ['CCavenue', 'remit guru', 'Infibeam'],
#  ['aequm', 'undisclosed investors'],
#  ['IdeaSpring Capital', 'zapty'],
#  ['vernacular.ai', 'Kstart Capital'],
#  ['Innovations East', 'telr'],
#  ['undisclosed investors', 'genie'],
#  ['paysense', 'Jungle Ventures'],
#  ['the good life', 'Ayesha Takia Azmi', 'Abu Farhan Azmi'],
#  ['pumpkart', 'Dr. Ritesh Malik'],
#  ['Ant Financial',
#   'SoftBank Group',
#   'paytm',
#   'Ratan Tata',
#   'MediaTek Inc.',
#   'Alibaba',
#   'Alibaba Group',
#   'Ant Financial Services (Alipay)'],
#  ['Akash Garg', 'ezcred', 'Rajesh Yohannan', 'Dheeraj Pandey'],
#  ['Hyderabad Angels', 'healthsutra', 'Ankur Capital'],
#  ['Tiger Global Management',
#   'delhivery',
#   'Times Internet',
#   'Tiger Global',
#   'Nexus Venture Partners',
#   'Fosun International',
#   'Multiples Alternate Asset Management',
#   'Carlyle Group'],
#  ['zipgrid', '1Crowd', '1Crowd (through crowd funding)', 'JLL'],
#  ['travelspice', 'Eagle10 Ventures'],
#  ['',
#   'Lightspeed India Partners',
#   'magicpin',
#   'Waterbridge Ventures',
#   'Lightspeed India',
#   'Vy Capital',
#   'Lightspeed Venture Partners'],
#  ['Nandan Nilekani',
#   'Kiran Mazumdar-Shaw',
#   'the print',
#   'Vijay Shekhar Sharma',
#   'Ratan Tata',
#   'Uday Kotak',
#   'Rajiv C Mody'],
#  ['Trifecta Capital', 'Mayfield Ventures', 'box8', 'IIFL Seed Ventures Fund'],
#  ['gennext students', 'Undisclosed Investors'],
#  ['Accion', 'Blue Orchard', 'SAIF Partners', 'aye finance'],
#  ['whatsloan', 'Lahiri Music’s family office'],
#  ['PV Sahad', 'Sandeep Shroff', 'Rahul Gupta', 'nivesh'],
#  ['wowflux', 'Undisclosed Investors'],
#  ['Carpediem Capital', 'collateral medical'],
#  ['loadshare', 'Matrix Partners'],
#  ['simplilend', 'Undisclosed Investors'],
#  ['supr daily',
#   'Anirudh Damani',
#   'Great Oaks Ventures',
#   'Dr. Apoorv Ranjan Sharma',
#   'Soma Capital',
#   'Anuj Golecha',
#   'Anil Jain',
#   '122 West Ventures',
#   'Krishna Jhunjhunwala',
#   'Y Combinator'],
#  ['RB Investments & existing investors',
#   'Accel Partners',
#   'Nasper',
#   'Harmony Partners',
#   'swiggy',
#   'DST Global',
#   'Norwest Venture Partners',
#   'Accel India',
#   'Bessemer Venture Partners',
#   'SAIF Partners'],
#  ['sastasundar', 'Rohto Pharmaceutical'],
#  ['', 'Mathew Cyriac', 'Florintree Advisors', 'cashe'],
#  ['eruditus', 'Bertelsmann India'],
#  ['Matrix Partners India', 'testbook', 'S Chand & Co'],
#  ['healthcare at home', 'Quadria Capital Advisors'],
#  ['tyre express', 'IvyCamp Ventures', 'Rohitash Gupta'],
#  ['smartcoin', 'Unicorn India Ventures & Others'],
#  ['Aspada Investments', 'waycool'],
#  ['Bessemer Venture Partners', 'perfios'],
#  ['Helion Venture Partners',
#   'Vispi Daver',
#   'GSF and Other angel investors',
#   'Aneesh Reddy',
#   'Girish Mathrubootham',
#   'Stellaris Venture Partners',
#   'whatfix',
#   'Helion Venture Partner',
#   'Gokul Rajaram',
#   'Powerhouse Ventures'],
#  ['Norwest Venture Partners', 'Kalaari Capital', 'elastirun'],
#  ['MMY co-Founder',
#   'Gujarat based angel investors',
#   'trukky',
#   'Keyur Joshi',
#   'Pavan Bakeri'],
#  ['Lomesh Agarwal',
#   'Koen Bouwers',
#   'konsult app',
#   'Jeroen Mensen',
#   'Pablo van den Bosch & Others'],
#  ['credit sudhaar', 'Deepak Kulkarni', 'Sandeep Pangal'],
#  ['fingerlix', 'Zephyr Peacock India'],
#  ['Herb Madan',
#   'WaterBridge Ventures',
#   'FreakOut Group',
#   'dataweave',
#   'Blume Ventures'],
#  ['F-Prime Capital Partners',
#   'Eight Roads Ventures',
#   'Mahindra Partners',
#   'Fidelity Growth Partners',
#   'medwell ventures',
#   'Fidelity Biosciences'],
#  ['Accel Partners',
#   'Flipkart',
#   'Shunwei Capital',
#   'mech mocha',
#   'Blume Ventures'],
#  ['', 'YouWeCan Ventures', 'startup buddy'],
#  ['qorqi', 'Paytm'],
#  ['Farhaan Shabbir', 'twenty two motors', 'Ishwar Singh'],
#  ['',
#   'Orios Venture Partners',
#   'Trifecta Capital',
#   'pharmeasy',
#   'Bessemer Venture Partners'],
#  ['wonderchef', 'Labruyere Eberlé'],
#  ['GrowX Ventures',
#   'Lightspeed India Partners',
#   'fastfox',
#   'CyberAgent Ventures',
#   'Blume Ventures',
#   'IMJ Investment Partners'],
#  ['Saurabh Arora', 'L.D Sharma', 'Rajan Anandan', 'omnify'],
#  ['Creation Investments Capital Management',
#   'IFMR Capital Finance',
#   'Aspada',
#   'Sequoia Capital',
#   'Mahindra and Mahindra Financial Services',
#   'Aspada Ventures',
#   'capital float',
#   'SAIF Partners'],
#  ['ninjacart',
#   'Accel Partners',
#   'Zop Smart',
#   'Qualcomm Ventures',
#   'Nandan Nilekani’s NRJN Trust',
#   'M&S Partners',
#   'Mistletoe'],
#  ['Philippe Bouchet', 'mergerware'],
#  ['sports flashes', 'Sandeep Singh', 'Sushil Kumar'],
#  ['clovia',
#   'Ivycap Ventures Advisors',
#   'IvyCap Ventures',
#   'Singularity Ventures and Ravi Dhariwal'],
#  ['emiza', 'Nishant Rao', 'Dileep Nath', 'Mayfield'],
#  ['BizReach',
#   'DHI Group Inc',
#   'Beenext',
#   'Digital Garage',
#   'Prime Venture Partners',
#   'Beenos',
#   'hackerearth'],
#  ['Amit Ranjan',
#   'Contrarian Capital',
#   'Abstract Ventures',
#   'Axilor Ventures',
#   'squadrun',
#   'Zishaan Hayath',
#   '91springboard',
#   'Blume Ventures',
#   'Emergent Ventures',
#   'Powai Lake Ventures',
#   'Deepinder Goyal',
#   'Anthill Ventures'],
#  ['R Ramaraj',
#   'MAPE Advisory Group',
#   'Corvus Ventures',
#   'tinmen',
#   'Lead Angel Network'],
#  ['scoutmytrip', 'Z Nation Lab'],
#  ['Redcliffe Capital', 'safetykart'],
#  ['', 'Urrshila Kerkar', 'weareholidays'],
#  ['Newbie Promoter Pvt Ltd',
#   'mall Industries Development Bank of India (SIDBI)',
#   'myly'],
#  ['credihealth', 'Mountain Pine Capital', 'Rajat Malhotra', 'Tolaram Inc'],
#  ['navia life care', 'Benori Ventures LLP'],
#  ['Jacqueline Fernandez', 'raw pressery'],
#  ['Nibhrant Shah',
#   'snackible',
#   'Anandbir Singh',
#   'Vikram Mehta',
#   'Anirudh Sheth',
#   'Pratik Singhi',
#   'Murali Nair'],
#  ['Arun Malhotra',
#   'Gaurav Kachru',
#   'Jatin Aneja',
#   'Sundeep Singh Sahni',
#   'be u salons'],
#  ['Village Capital', 'simulanis'],
#  ['IndiaNivesh Venture Capital Fund', 'innefu security consulting'],
#  ['whodat', 'Ideaspring Capital'],
#  ['Exfinity Venture Partners', 'absentia vr'],
#  ['iotrek', 'Undisclosed Investor'],
#  ['SIDBI Venture Capital Ltd',
#   'Ratan Tata',
#   'holachef',
#   'Kalaari Capital',
#   'India Quotient'],
#  ['Amit Gupta',
#   'Naveen Tewari',
#   'Sistema Asia Fund',
#   'Abhay Singhal',
#   'Helion Ventures',
#   'Ankit Nagori',
#   'wooplr',
#   'Astarc Ventures',
#   'Raghunandan G',
#   'Anand Chandrasekaran',
#   'Piyush Shah',
#   'Rajiv Mehta',
#   'Amereus Group'],
#  ['video ken',
#   'Sashi Reddi',
#   'LG Chandrasekhar',
#   'Surot Chatterjee',
#   'Ashish Agrawal',
#   'Ravi Garikipati'],
#  ['Lightbox Expansion Fund',
#   'Sequoia Capital India',
#   'faasos',
#   'Sequoia Capital',
#   'Ligthbox Ventures II',
#   'ru-Net',
#   'RuNet South Asia',
#   'RB Investments',
#   'Lightbox Ventures'],
#  ['DSG Consumer Partners and Venture Nursery',
#   'Sequoia Capital India Advisors',
#   'SoftBank Group',
#   'Lightspeed India',
#   'LightSpeed Ventures',
#   'SoftBank Vision Fund',
#   'Greenoaks Capital Partners',
#   'Lightspeed Venture Partners',
#   'Sequoia Capital',
#   'Greenoaks capital',
#   'Softbank',
#   'Greenoaks Capital',
#   'oyo'],
#  ['Helion Ventures',
#   'Fidelity Growth Partners India',
#   'toppr',
#   'WGG International',
#   'SAIF Partners'],
#  ['niramai', 'Axilor Ventures', 'pi Ventures', '500 Startups', 'Binny Bansal'],
#  ['the office pass', 'Arun Tadanki', 'Aditya Verma'],
#  ['awfis', 'Sequoia India'],
#  ['myra', 'Matrix Partners', 'Times Internet'],
#  ['Sunrise Capital GmBH',
#   'flytxt',
#   'DAH Beteiligungs GmbH',
#   'Big Data Investments B.V'],
#  ['howdy ventures', 'S. Xavier Britto'],
#  ['Mato Peric',
#   'Littlerock',
#   'Trifecta Capital',
#   '500 Startups',
#   'Peter Kabel & others',
#   'Singularity Ventures',
#   'stalkbuylove'],
#  ['Omidyar Networks',
#   'Orios Ventures Partners',
#   'zipgo',
#   'Team Builder Ventures'],
#  ['Khattar Holdings', 'scootsy', 'Agnus Capital'],
#  ['autobix', 'GardX International'],
#  ['eshiksha', 'Cross Border Angels & Experts'],
#  ['inurture', 'BlackSoil Capital Pvt. Ltd'],
#  ['sepalika', 'Accel Partners'],
#  ['mintwalk', 'Poshika Financial Ecosystem'],
#  ['NB Ventures', 'Idein Ventures', 'qriyo'],
#  ['Kunal Bahl',
#   'Sequoia Capital India',
#   'Blume Ventures',
#   'Phanindra Sama',
#   'Rohit Bansal',
#   'Raju Reddy',
#   'belong'],
#  ['Calcutta Angels Network (CAN)', 'seenit', 'Augment Ventures'],
#  ['Nandkumar Rane',
#   'Anupam Tyagi',
#   'LN Buddharaju',
#   'Harsh Kundra',
#   'paalak',
#   'Vishwadeep Bajaj'],
#  ['F-Prime Capital Partners',
#   'Eight Roads Ventures',
#   'Ventureast',
#   'celes care',
#   'Endiya Partners'],
#  ['karomi', 'Ideaspring Capital'],
#  ['red carpet', 'Lightspeed Venture Partners'],
#  ['Langoor', 'kreate konnect'],
#  ['Elevar Equity',
#   'Accion Venture Lab',
#   'Quona Capital',
#   'creditmantri',
#   'IDG Ventures India'],
#  ['Chandigarh Angels Network',
#   'Social Alpha and other unnamed angel investors',
#   'lets endorse'],
#  ['tydy', 'Sanjay Sathe', 'Jayesh Parekh', 'Bhupen Shah'],
#  ['Sandeep Aggarwal', 'nactus', 'Gautam Chhaochharia', 'R Balachandar'],
#  ['Bennett', 'Coleman and Company Ltd', 'oho shop'],
#  ['Undisclosed angel investors', 'emojifi'],
#  ['CDC Group Plc', 'igenetics'],
#  ['Atul Nishar', 'juno clinic'],
#  ['Aneesh Seth', 'Tushar Mittal', 'summerlabel'],
#  ['pickme', 'SIDBI Venture Capital Fund'],
#  ['agrostar', 'IDG Ventures', 'Accel Partners'],
#  ['Dhiraj Rajaram',
#   'Sanjay Nath',
#   'Flipkart',
#   'Micromax',
#   'Samir Bangara',
#   'Star India Pvt Ltd',
#   'zapr',
#   'Dinesh Agarwal',
#   'Ambiga Dhiraj',
#   'Arihant Patni',
#   'Saavn'],
#  ['data resolve', 'IDFC Parampara Early Stage Opportunities Fund'],
#  ['National Science and Technology Entrepreneurship Development Board',
#   'book servicing'],
#  ['blowhorn',
#   'Unitus Seed Fund',
#   'Michael & Susan Dell Foundation',
#   'IDG Ventures India',
#   'Draper Associates'],
#  ['Warburg Pincus',
#   'SAIF Partners and others',
#   'rivigo',
#   'Private Sector Banks (Debt Funding)'],
#  ['IDG ventures',
#   'pipecandy',
#   'Axilor Ventures',
#   'Emergent Ventures',
#   'Indian Angel Network'],
#  ['SEGNEL Ventures', 'Kae Capital', 'parentune'],
#  ['appbrowzer', 'Deepak Gurnani'],
#  ['Times Internet Ltd', 'magicbricks'],
#  ['peebuddy', 'Indian Angel Network'],
#  ['iorderfresh', 'Best Foodworks', 'Singapore Angel Network'],
#  ['lavelle networks', 'Ideaspring Capital'],
#  ['Asuka', 'propertyshare', 'BEENEXT', 'Pravega Ventures'],
#  ['Cyber Carrier', 'mydermacy'],
#  ['latestone',
#   'Bharat Sheth',
#   'Florintree',
#   'Chidambaram Palaniappan',
#   'Mathew Cyriac',
#   'Palred Technologies Ltd'],
#  ['Undisclosed Investor', 'frapperz'],
#  ['', 'IDG Ventures', 'mpaani', 'Saha Fund', 'Blume Ventures'],
#  ['Puneet Gupta', 'Nimitt Desai & Others', 'shilpmis'],
#  ['Atul Goel',
#   'Kalaari Capital and IDG Ventures India',
#   'popxo',
#   'Summit Media',
#   'and Gurpreet Singh',
#   'GREE Ventures'],
#  ['fitso',
#   'Samar Singla',
#   '',
#   'Varun Khurana',
#   'Yashish Dhaiya',
#   'Vinay Bansal',
#   'Sujeet Kumar',
#   'Bhupender Singh'],
#  ['farmart', 'Indian Angel Network'],
#  ['airpay', 'Rakesh and Rajesh Jhunjhunwala', 'Kalaari Capital'],
#  ['L’Occitane', 'myglamm'],
#  ['Nandu Nandkishore', 'Shripad Nadkarni', 'the mons co.'],
#  ['', 'Sandeep Raju', 'Ravi Saxena', 'haqdarshak'],
#  ['Micromax Informatics', 'Sequoia Capital', 'Kinzon Capital', 'ixigo'],
#  ['markets and markets', 'FTV Capital', 'Zodius Capital'],
#  ['Ojas Ventures', 'bizom'],
#  ['babyonboard',
#   'Gaurav Luniya',
#   'Rohit Sethi',
#   'Mahavir Sharma',
#   'Vishal Jain'],
#  ['', 'Vikas Bajaj', 'sport flashes', 'Amit Kharbanda'],
#  ['Aarin Capital Partners', '3one4 capital', 'wigzo', 'TV Mohandas Pai'],
#  ['Brand Capital', 'donething'],
#  ['zapyle', 'Undisclosed Investors'],
#  ['Puneet Motihar', 'ithaka', 'Ankit Gupta'],
#  ['perpule', 'KStart Capital'],
#  ['Sistema Asia Fund',
#   'Mayfield India',
#   'TV Mohandas Pai',
#   '3one4 Capital',
#   'Neoplux Technology Fund',
#   'licious',
#   'Kanwaljit Singh',
#   'Mayfield India II Management Ltd'],
#  ['Prof. Ram Kumar Kakani & Others',
#   'Mudit Saxena',
#   'medinfi',
#   'Prijit Debnath',
#   'Vinod Martin',
#   'Pradeep K Jaisingh',
#   'Rajnish Sinha',
#   'Evan Lim',
#   'Ram Kumar Kakani',
#   'Gurmeet Chahal & Others',
#   'Sunil T V',
#   'Vijay Ghadge',
#   'Kanchan Ghoshal',
#   'Hemant Kaul'],
#  ['', 'indus os', 'JSW Ventures', 'VenturEast', 'Omidyar Network'],
#  ['Nikhil Arora',
#   'Risabh Gupta',
#   'Nitish Singh',
#   'Meet Kanodia',
#   'emflux motors',
#   'Krit Sankalp',
#   'Meher Roy'],
#  ['Om Chaudhry', 'klinic app'],
#  ['oriano solar', 'Samridhi Fund'],
#  ['Abraaj Group',
#   'Trifecta Capital',
#   'Bessemer Venture Partners',
#   'bigbasket'],
#  ['Dhruv Chitgopekar',
#   'rooter',
#   'Intex Technologies',
#   'Prantik Dasgupta',
#   'Boman Irani'],
#  ['LetsVenture', 'falconbrick', 'Satveer Thakral', 'Mumbai Angels'],
#  ['e.ventures',
#   'Eight Roads Ventures',
#   'Fidelity Growth Partners India',
#   'Greycroft Partners',
#   'B Capital Group',
#   'Fidelity Growth Partners',
#   'Ignition Partners',
#   'Greycroft',
#   'icertis'],
#  ['clodura', 'Undisclosed Investors'],
#  ['stockroom.io', 'Satya D Sinha', 'Gyanendra Singh', 'Undisclosed Investors'],
#  ['Jaarvis Accelerator', 'imanagemyhotel'],
#  ['Batlivala & Karani Securities', 'Venture Works', 'inner hour'],
#  ['RB Investments',
#   'travel triangle',
#   'Bessemer Venture Partners',
#   'SAIF Partners'],
#  ['wandertrails', 'Earlsfield Capital'],
#  ['Rajan Anandan',
#   'Kunal Bahl',
#   'pi Ventures',
#   'Rahul Khanna',
#   'zenatix',
#   'Blume Ventures',
#   'Rohit Bansal'],
#  ['Temasek Holdings', 'March Capital', 'Warburg Pincus', 'cartrade'],
#  ['Japan Vyas', 'mindyourfleet', 'Tarun Adlakha'],
#  ['edurev', 'Pradeep Reddy Kamasan', 'Facebook FB Start programme'],
#  ['InnoVen Capital',
#   'Seedfund',
#   'voonik',
#   'Sequoia Capital',
#   'RB Investments'],
#  ['1crowd', 'Ganesh Natarajan'],
#  ['Al Dhaheri family', '48east'],
#  ['ThinQbate', 'redesyn'],
#  ['sigtuple',
#   'IDG Ventures',
#   'Accel Partners',
#   'pi Ventures',
#   'Accel Partners & Others',
#   'Axilor Partners',
#   'VH Capital',
#   'Sachin Bansal',
#   'Binny Bansal',
#   'Endiya Partners'],
#  ['Lumis Partners', 'Vertex Ventures', 'flutura'],
#  ['Praveen Sinha',
#   'B S Nagesh',
#   'Anil Jain & other HNIs',
#   'Arun Chandra Mohan',
#   'wassup'],
#  ['better mortgage', 'Pine Brook', 'Goldman Sachs', 'Kleiner Perkins'],
#  ['nurturey', 'Seedrs Crowd funding platform', 'Mohit Joshi & Others'],
#  ['fyle', 'Pravega Ventures'],
#  ['Girish Mathrubootham', 'gobumpr', 'Mahalingam K'],
#  ['NSI Infinium Global Pvt. Ltd', 'Infibeam', 'ccavenue'],
#  ['Umang Moondra', 'connaizen', 'Vikram Sud'],
#  ['Utsav Somani',
#   'Rajan Anandan',
#   'Girish Mathrubootham',
#   'Kunal Shah',
#   'Vishal Gondal',
#   'Punit Soni',
#   'Vijay Shekhar Sharma',
#   'Anand Chandrasekaran',
#   'Sunil Kalra',
#   'innov8',
#   'Vikram Limaye'],
#  ['Ribbit Capital', 'Omidyar Network', 'zestmoney', 'PayU'],
#  ['Quake Capital', 'airzaar'],
#  ['Tekton Ventures',
#   'truebil',
#   'Shunwei Capital',
#   'Anupam Mittal',
#   'Kalaari Capital',
#   'Kae Capital',
#   'Inventus Capital'],
#  ['T V Mohandas Pai',
#   'Qualcomm',
#   'Kalaari Capital Partners',
#   'Karthee Madasamay',
#   'yourstory',
#   'Ratan Tata',
#   '3ONE4 Capital Advisors',
#   'Vani Kola',
#   'UC-RNT'],
#  ['SRI Capital', 'imaginate'],
#  ['Deepak Natraj',
#   'Girish Mathrubootham',
#   'Pallav Nadhani',
#   'Pavan Ongole',
#   'Mahesh Murthy',
#   'the ken',
#   'Sandeep Mathur',
#   'Vijay Shekhar Sharma & Others',
#   'Aprameya Radhakrishna'],
#  ['urban ladder',
#   'Venky Harinarayan',
#   'TR Capital',
#   'Sequoia Capital',
#   'Steadview Capital',
#   'Kalaari Capital',
#   'Anand Rajaraman',
#   'SAIF Partners'],
#  ['ah! Ventures',
#   'LetsVenture',
#   'White Unicorn Ventures',
#   'Konglo Ventures',
#   'aisle',
#   'TermSheet'],
#  ['townscript', 'Group of Angel Investors', 'BookMyShow'],
#  ['Facebook FBStart', 'leopetra'],
#  ['blood n care', 'Facebook FBStart'],
#  ['Softbank Ventures Korea',
#   'SoftBank Ventures Korea',
#   'IMM Investment',
#   'true balance'],
#  ['Anupam Mittal', 'Facebook FBStart', 'Sharad Sharma & 14 others', 'vebbler'],
#  ['BEENEXT',
#   'get my parking',
#   'Sunil Munjal',
#   'Indian Angel Network (IAN)',
#   'The Chennai Angels'],
#  ['Nitin Saluja', 'Sandeep Tandon', 'Kunal Shah', 'lets reap', 'Gagan Goyal'],
#  ['Yogesh Agarwal', 'oglas', 'Pankaj Rungta'],
#  ['staydobe', 'Ishan Manaktala'],
#  ['Ashish Chand',
#   'Rohit',
#   'Ashish Gupta',
#   'Chandigarh Angels',
#   'Sunil Singh & Others',
#   'biryani by kilo'],
#  ['johari shop', 'Undisclosed Investors'],
#  ['Paragon Trust', 'Brand Capital', 'neostencil'],
#  ['Yuri Milner',
#   'Tiger Global Management',
#   'IFC',
#   'Accel Partners',
#   'Flipkart',
#   'Sands Capital',
#   'Sanjiv Rangrass',
#   'Apoletto',
#   'blackbuck'],
#  ['taxsutra',
#   'T V Mohandas Pai',
#   'PV Srinivasan',
#   'TV Mohandas Pai',
#   'V Balakrishnan'],
#  ['tempogo', 'K2 Capital'],
#  ['Anand Chandrasekaran', 'Ramakant Sharma', 'Rajiv Mehta', 'gofynd'],
#  ['vow car clinic', 'Vishal Malik'],
#  ['learntron', 'Kae Capital'],
#  ['mobident',
#   'DanGold Investment Corp',
#   'Centre for Innovation Incubation and Entrepreneurship (CIIE)'],
#  ['yostra', 'Marico Innovation Foundation (MIF)', 'Villgro'],
#  ['India Nivesh Growth Fund',
#   'TCI Ventures',
#   'Sixth Sense',
#   'leap india',
#   'Mayfield Ventures'],
#  ['Valiant Capital',
#   'Tybourne Capital',
#   'RuNet and Sofina',
#   'freecharge',
#   'Sequoia Capital',
#   'Jasper Infotech Pvt Ltd'],
#  ['ticketnew', 'Alibaba Pictures'],
#  ['BlackSoil Capital Pvt Ltd', 'intelligence node'],
#  ['Trifecta Capital', 'securens', 'Mayfield India'],
#  ['Toos N Daruvala', 'loan frame', 'Vedanta Capital', 'William Campbell'],
#  ['driveskool', 'Aavya Ventures'],
#  ['PremjiInvest',
#   'TPG Growth',
#   'Kris Gopalakrishnan',
#   'Ronnie Screwvala',
#   'lenskart',
#   'IDG Ventures',
#   'Adveq Management',
#   'TR Capital',
#   'Ratan Tata',
#   'International Finance Corp'],
#  ['instaoffice', 'Mohit Satyan', 'Zishaan Hayath', 'Karan Chellani'],
#  ['Mekin Maheshwari',
#   'IDG Ventures',
#   'hansel.io',
#   'Rajesh Sawhney',
#   'Endiya Partners'],
#  ['ADAG Reliance Private Equity',
#   'Andre Hoffman',
#   'Lohia Group',
#   'Undisclosed Investors',
#   'square yards'],
#  ['Deutsche Telekom Strategic Investments & Others', 'roambee'],
#  ['Vividhity Ventures', 'paisawapas'],
#  ['Blume Ventures',
#   'Girish Mathrubootham',
#   'iservice',
#   'Aprameya Radhakrishna'],
#  ['Phanindra Sama',
#   'Rajan Anandan',
#   'unacademy',
#   'Sujeet Kumar',
#   'Nexus Venture Partners',
#   'Blume Ventures',
#   'Sumit Jain',
#   'Aprameya Radhakrishna'],
#  ['secururax',
#   'Axilor Ventures',
#   'Parampara Early Stage Opportunities Fund & Others'],
#  ['Harsh V. Pant', 'Ratheesh Raveendran', 'leadburg'],
#  ['zolostays', 'Nexus Venture Partners', 'Innoven Capital'],
#  ['oi media', 'Quarizon'],
#  ['hipcouch', 'Undisclosed Investors'],
#  ['Unitus Seed Fund', 'Menterra Social Impact Fund', 'curiositi'],
#  ['Flipkart Logistics Pvt. Ltd', 'tinystep', 'Flipkart', 'Matt Glickman'],
#  ['Yuri Milner',
#   'Sequoia Capital Global Equities',
#   'Matrix Partners',
#   'Altimeter Capital',
#   'Sofina',
#   'Thrive Capital',
#   'practo',
#   'Tencent',
#   'Sequoia Capital',
#   'ru-Net',
#   'Google Capital',
#   'RSI Fund'],
#  ['India Quotient and others', 'ketchupp'],
#  ['hoopy', 'undisclosed investors'],
#  ['Ajith Nair', 'ezytruk', 'Anish K'],
#  ['kratikal', 'Praveen Dubey', 'J.P. Bhatt', 'Amajit Gupta'],
#  ['direct create', 'Rajasthan Venture Capital Fund'],
#  ['Mumbai Angels Network',
#   'Singapore Angel Network',
#   'Fireside Ventures',
#   'vahdam teas'],
#  ['SB Ventures', 'pparke'],
#  ['Reema Kagati',
#   'Rajan Anandan',
#   'Ruchi Narain',
#   'weddingz.in',
#   'Amrish Kumar',
#   'Hrishikesh Parandekar',
#   'Zoya Akhtar',
#   'Singularity Ventures'],
#  ['Native Angels Network', 'native special', 'Indian Angel Network'],
#  ['fitnapp', 'SD Group'],
#  ['ethosh', 'Deepak Nathani'],
#  ['wydr',
#   'Axis Capital',
#   'Sandeep Aggarwal',
#   'Jungle Venture Partners',
#   'Stellaris Venture Partners',
#   'Bessemer Venture Partners'],
#  ['messagif', 'Undisclosed investor'],
#  ['smarthi', 'Singapore based investor'],
#  ['YourNest Fund II', 'cron systems'],
#  ['Sequoia India',
#   'cuemath',
#   'Sequoia Capital',
#   'Unitus Seed Fund',
#   'CapitalG'],
#  ['India Educational Investment Fund', 'chippersage'],
#  ['India Educational Investment Fund', 'selectjobs'],
#  ['Anglian Omega Network', 'Indochine International', 'khel now'],
#  ['Iron Pillar and IIFL', 'Omidyar Network', 'nowfloats', 'Blume Ventures'],
#  ['lets transport', 'GMO Japan', 'Neelesh Bhatnagar'],
#  ['betaout',
#   'Amit Ranjan',
#   'Mumbai Angels',
#   'LetsVenture',
#   'Kunal Bahl',
#   'Stanford Angels',
#   'Vijay Shekhar Sharma',
#   'East Ventures & Others',
#   'Chennai Angels',
#   'Hyderabad Angels',
#   'Girish Mathrubootham &\xa0 Group of other Angel investors'],
#  ['Amit Ranjan',
#   'Rajan Anandan',
#   'Deep Kalra & Others',
#   'wishberry',
#   'Alok Mittal & others',
#   'Shankar Mahadevan',
#   'Sharad Sharma'],
#  ['rml agtech', 'IvyCap Ventures'],
#  ['Senovo',
#   'Unternehmertum Venture Capital',
#   'Alexander Bruehl',
#   'loyaltyprime'],
#  ['instasafe', 'ABM Knowledgeware', 'Group of Investors'],
#  ['Bennett', 'Coleman and Company Ltd', 'infibeam'],
#  ['Dream Incubator', '99games'],
#  ['Brand Capital', 'airmed labs'],
#  ['V Aanand R', '99perhour'],
#  ['kochi post', 'Rajesh Yohannan', 'Puthen & Cole'],
#  ['intuit things', 'Sanjay Mehta & Others ( The Ten Minute Million)'],
#  ['The Ten Minute Million', 'cloudrino'],
#  ['The Ten Minute Million', 'fabx'],
#  ['The Ten Minute Million', 'maptags'],
#  ['Chandigarh Angels Network (CAN)', 'yolo health'],
#  ['Undisclosed investors', 'heads up for tails', 'Undisclosed Investors'],
#  ['register my marriage', 'Mumbai Angels'],
#  ['SQue Capital', 'Grace Capital Ventures', 'sidqam', 'Soham Vencaps'],
#  ['American Express Ventures',
#   'india lends',
#   'AdvantEdge Partners',
#   'Cyber Carrier VC',
#   'DSG Consumer Partners'],
#  ['Songhyun Investment', 'slide app'],
#  ['badiyajobs', 'Undisclosed'],
#  ['streo', 'Quarizon', 'GEMs Advisory'],
#  ['tygr', 'Franchise India'],
#  ['IvyCamp Ventures', 'mr hot foods'],
#  ['Jupiter Capital', 'Lakshmi Vilas Bank & undisclosed HNIs', 'urdoorstep'],
#  ['onn bikes', 'Grace Capital Ventures'],
#  ['Info Edge (India)', 'Info Edge (India) Ltd', 'diro labs'],
#  ['Ajith Sukumaran', 'Currae Healthtech Fund', 'thb'],
#  ['lookatme', 'Eros Labs'],
#  ['LetsVenture', 'The Chennai Angels', 'netree'],
#  ['Anbu Pandian',
#   'Lead Angels',
#   'Investors from Mumbai Angels & LetsVenture',
#   'Mumbai Angels',
#   'LetsVenture',
#   'Girish Mathrubootham',
#   'Zishaan Hayath',
#   'Singapore Angel Network',
#   'bookeventz'],
#  ['tailslife', 'Mohan Kumar', 'V. Balakrishnan'],
#  ['revv', 'Edelweiss Private Equity'],
#  ['wealthapp',
#   'Arjun Sharmaa',
#   'Vikram Kotak',
#   'Venk Krishnan',
#   'Ramkumar Nishtal',
#   'Jayant Davar',
#   'MJ Aravind'],
#  ['Appliyifi', 'Calcutta Angel Network', 'vehico'],
#  ['zest money', 'PayU'],
#  ['Venture Catalysts', 'gomechanic'],
#  ['stalk buy love', 'Kalaari Capital', 'William Bissel'],
#  ['Dalip Pathak',
#   'Michael Carlos',
#   'Sunil Munjal',
#   'Harsh Mariwala',
#   'nykaa',
#   'Max Ventures and Industries',
#   'Atul Nishar',
#   'Mariwala family'],
#  ['wittyparot', 'Mumbai Angels'],
#  ['neuroequilibrium', 'Unicorn India Ventures'],
#  ['xseed education', 'Verlinvest SA'],
#  ['rupaiya exchange', 'Undisclosed Investors'],
#  ['BrahmaX Ventures', 'doctor insta', 'Rishi Parti', 'RoundGlass Partners'],
#  ['undisclosed investors', 'Axilor', 'urbanpiper'],
#  ['Siddhartha Gupta', 'Ashvin Chadha', 'fresh food concepts'],
#  ['Rajan Anandan',
#   'Accel Partners',
#   'Abhishek Goyal',
#   'Pramod Bhasin',
#   'Elevar Equity',
#   'Gaurav Dalmia',
#   'Gagan Hasteer',
#   'indifi',
#   'Omidyar Network',
#   'Arun Tadanki'],
#  ['Nobel House',
#   'Rajesh Yabaji',
#   'Rajul Garg',
#   'Ramasubramaniam B',
#   'Sunstone Capital',
#   'gocomet',
#   'India Quotient',
#   'Chanakya Hridaya',
#   'Vishwanathan'],
#  ['Matrix Partners India',
#   'ofbusiness',
#   'Matrix Partners',
#   'Zodius Technology Opportunities Fund'],
#  ['Green House Ventures', 'GHV', 'FiNC', 'fitmein'],
#  ['Anbu Pandian', 'qacco', 'Prabhakar MR & Others', 'Lead Angels Network'],
#  ['Anand Chandrasekaran',
#   'Helion Venture Partners',
#   'Exfinity Ventures',
#   'moengage'],
#  ['Bhupen Shah & Others', 'V. Krishna Prasad', 'ten3t health'],
#  ['trading bells', 'Swastika Investmart Ltd'],
#  ['Digital Financial Service Lab', 'serv’d'],
#  ['Infosys Innovation Fund', 'ideaforge', 'WRV Capital and IndusAge Partners'],
#  ['amagi media labs',
#   'Emerald Media',
#   'Premji Invest & Mayfield Fund',
#   'Premji Invest'],
#  ['pocket aces',
#   'Sandeep Tandon',
#   'Axilor Ventures',
#   'Sequoia Capital India',
#   'Kunal Shah',
#   'North Base Media',
#   '3one4 Capital',
#   'Aarin Capital'],
#  ['pi data centers', 'Epsilon Venture Partners'],
#  ['GEMS Advisory', 'tripshelf', 'Quarizon', 'GEMS group'],
#  ['Axilor Ventures', 'events high'],
#  ['nobroker',
#   'Mamoru Taniya',
#   'KTB Network',
#   'BEENEXT',
#   'Vijay Shekhar Sharma',
#   'Anand Chandrasekaran',
#   'Digital Garage',
#   'Beenext',
#   'Fulcrum Ventures',
#   'Beenos',
#   'Qualgro',
#   'SAIF Partners'],
#  ['vivocarat', 'Undisclosed Investors'],
#  ['Ajith Nair', 'tiyo'],
#  ['zoomcar',
#   'Ford Smart Mobility Llc',
#   'Empire Angels',
#   'NGP',
#   'Sequoia Capital',
#   'Cyber Carrier CL'],
#  ['the bluebook', 'Let’s Venture', 'Indian Angel Network'],
#  ['Fireside Ventures & Others', 'mamaearth'],
#  ['vegetall', 'The Chennai Angels'],
#  ['HCS Venture capital fund', 'innoplexus'],
#  ['mindler', 'Taxmann'],
#  ['mcaffeine',
#   'Kaushal Agarwal',
#   'Harminder Sahani',
#   'Pranay Jivrajka',
#   'Navjot Saini',
#   'KK Mehra'],
#  ['enkast', 'Ivy League Alumni Angel Network'],
#  ['shopkirana',
#   'Anil Gelra',
#   'Incubate Fund',
#   'Lead Angels Group & Others',
#   'Jaikumar Nair',
#   'Atul Jain'],
#  ['S. Somasegar & Others', 'Pradyumna Dalmia', 'myadvo'],
#  ['Quarizon', 'asocon'],
#  ['lexcomply', 'Ajay Relan'],
#  ['Aruna Ganesh Ram', 'the postbox', 'The Chennai Angels', 'Ritesh Mehta'],
#  ['pandorum technologies', 'Binny Bansal', 'Sachin Bansal'],
#  ['undisclosed investors', 'dekkho'],
#  ['Eight Roads Ventures', 'shadowfox'],
#  ['shopx', 'Nandan Nilekani'],
#  ['Amit Gupta',
#   'Gopal Srinivasan',
#   'Micromax Informatics',
#   'Pallav Nadhani',
#   'Sashi Reddy',
#   'Blume Ventures',
#   'NB Ventures',
#   'healthifyme',
#   'IDG Ventures India',
#   'Inventus Capital'],
#  ['',
#   'WaterBridge Ventures',
#   'LetsVenture',
#   'Currae Healthtech Fund',
#   'Anupam Mittal',
#   'letsmd',
#   'Calcutta Angels Network'],
#  ['CoCreate Ventures', 'justbooks'],
#  ['Kaleden Holdings', 'instantpay', 'RB Investments'],
#  ['pickmylaundry', 'GHV Accelerator', 'Kedar Lele'],
#  ['Accel Partners',
#   'Google Capital & Accel Partners',
#   'Sequoia Capital India',
#   'Tiger Global',
#   'freshdesk'],
#  ['laundryanna', 'Undisclosed Investors'],
#  ['Rajat Jain',
#   'Vaibhav Jain',
#   'Yogesh Andlay',
#   'Ashish Gupta',
#   'Sanjay Bhasin',
#   'Raman Roy',
#   'Sumit Jain',
#   'sattviko'],
#  ['zarget',
#   'Accel Partners',
#   'Sequoia India',
#   'Girish Mathrubootham',
#   'Matrix Partners'],
#  ['Aarin Capital', 'Mumbai Angels', 'doselect', '3one4 Capital'],
#  ['', 'easypolicy', 'Unilazer Ventures'],
#  ['Gati Ltd', 'browntape'],
#  ['connect india', 'Aavishkaar', 'Aavishkaar Venture Management'],
#  ['corseco', 'Ameera Shah', 'Vivek Bhargava'],
#  ['vimmune', 'Undisclosed investor'],
#  ['the gourmet jar', 'Chandigarh Angels Network'],
#  ['medzin', 'A M Sikander'],
#  ['IDG Ventures', 'bizongo', 'Accel Partners'],
#  ['Dheeraj Jain & Other angel investors',
#   'Qasar Younis',
#   'justride',
#   'Axan Venture',
#   'Paul Bucche',
#   'Justin Kan',
#   'SCM Holdings',
#   'Susa Ventures',
#   'Kima Ventures'],
#  ['iim jobs', 'India Quotient'],
#  ['YourNest Angel Fund', 'iSON', 'golflan'],
#  ['yottaasys', 'Gleevoaz Ventures'],
#  ['Arun Seth',
#   'Deepak Ghaisas',
#   'tone tag',
#   'Anand Chandrasekaran',
#   'T.V. Mohandas Pai'],
#  ['life in control', 'RoundGlass Partners'],
#  ['Kalaari Capital Accelerator Program',
#   'IDG Ventures India',
#   'Kalaari Capital',
#   'active.ai'],
#  ['Norwest Venture Partners', 'elasticrun', 'Kalaari Capital'],
#  ['Helion Ventures', 'zefo', 'BEENEXT', 'Sequoia India'],
#  ['IDG Ventures India', 'playsimple', 'SAIF Partners'],
#  ['stasis labs', 'RTP-HC', 'Techstars Ventures & Others', 'Wonder Ventures'],
#  ['scienaptic', 'Pramod Bhasin'],
#  ['koovs',
#   'Times of India Group & Existing investors',
#   'HT Media Ltd',
#   'Waheed Alli',
#   'Nahata Family'],
#  ['lawrato', 'Indian Angel Network'],
#  ['R.S Sharma', 'trip tap toe'],
#  ['Quarizon', 'pictor imaging'],
#  ['gramcover', 'Omnivore Capital'],
#  ['aermed', 'Hitesh Windlass'],
#  ['workindia',
#   'Riddhesh Gandhi & Others',
#   'Keshav Sanghi',
#   'Beenext',
#   'Asuka Holdings',
#   'Satyen Kothari'],
#  ['bats on delivery', 'Devdeep Singh'],
#  ['numberz.in', 'Kae Capital', 'Khosla Impact'],
#  ['housing.com', 'Softbank Group', 'SoftBank Corp'],
#  ['Ameera Shah', 'awesummly', 'Vivek Bhargava'],
#  ['volt', 'YMS Mobitech'],
#  ['vymo', 'Sequoia India'],
#  ['Sanjai Vohra', 'V. Bunty Bohra', 'shubhloans'],
#  ['noddapp', 'Undisclosed multiple investors'],
#  ['Mayfield',
#   'Sequoia India',
#   'knowlarity',
#   'Delta Partners',
#   'Trifecta Capital',
#   'Blacksoil'],
#  ['Axilor Ventures', 'IDG Ventures', 'infisecure'],
#  ['Lightspeed US', 'udaan', 'Lightspeed Venture Partners India'],
#  ['froyofit', 'Dr. Pooja Gandhi'],
#  ['Unitus Seed Fund', 'Venture Highway', 'betterplace'],
#  ['Lightspeed India Partners',
#   'SAIF Partners',
#   'India Quotient',
#   'Venture Highway',
#   'sharechat'],
#  ['uclean', 'Franchise India'],
#  ['Barkawi Holdings GmbH',
#   'servify',
#   'BEENEXT',
#   'Sreevathsa Prabhakar',
#   'Blume Ventures',
#   'TM Service Technology Holdings Gmbh',
#   'TM Service Technology Holdings GmbH'],
#  ['VC Karthic',
#   'Umasankar Nistala',
#   'Miten Mehta',
#   'Girish Mathrubootham',
#   'hubilo',
#   'Rakesh Patel',
#   'Akash Bhavsar',
#   'Jeevanandhan Rajagopal',
#   'Vikas Chadha & Others'],
#  ['Reliance Entertainment', 'funongo'],
#  ['Xelpmoc', '121policy'],
#  ['Subramanya Venkat',
#   'Venk Krishnan',
#   'Paytm',
#   'Vijay Shekhar Sharma',
#   'tapchief',
#   'Aprameya Radhakrishna'],
#  ['kloseby', 'Undisclosed Investor'],
#  ['Manish Maheshwari', 'Contrarian Vriddhi Fund', 'wholesalebox'],
#  ['crossahead', 'Mohit Sharma'],
#  ['Kalaari Capital Accelerator Program',
#   'affordplan',
#   'Prime Venture Partners',
#   'Kalaari Capital'],
#  ['Shun Yoshida & Others',
#   'Lumina Datamatics',
#   'handytrain',
#   'Silver Range Investments'],
#  ['shopsup', 'Anand Sankeshwar', 'Yang Shu'],
#  ['indofash', 'Shekhar Sahu', 'Nitesh Pant'],
#  ['Dileep Bhatt', 'entropika', 'Milind Chaudhary'],
#  ['marianaiq', 'Exfinity Venture Partners'],
#  ['chai thela', 'Quarizon'],
#  ['interviewpad', 'Krishna Rokhale'],
#  ['Menterra Social Impact Fund', 'math buddy'],
#  ['pulse', 'SAIF Partners'],
#  ['carcrew.in', 'TVS Group'],
#  ['merakisan', 'Mahindra Univeg'],
#  ['Recruit Holdings', 'mystifly'],
#  ['American Express Ventures', 'Sequoia Capital', 'helpchat'],
#  ['Kris Gopalakrishnan',
#   'IDG Ventures',
#   'YourNest Angel Fund',
#   'uniphore',
#   'Indian Angel Network (IAN)'],
#  ['Viraj Tyagi & Others', 'Viraj Tyagi & others', 'world art community'],
#  ['giftxoxo', 'Mahindra Holidays & Resorts India Ltd'],
#  ['Sandeep Tandon',
#   'BeeNext',
#   'TV Mohandas Pai',
#   'Kunal Shah',
#   'bharat bazaar'],
#  ['New Enterprise Associates',
#   'goqii',
#   'Cheetah Mobile',
#   'Edelweiss Financial Services',
#   'Vijay Shekhar Sharma',
#   'Ratan Tata'],
#  ['Naveen Arya', 'india gifts portal', 'Tarun Joshi'],
#  ['Xchange Investors NV', 'netlinx', 'TransGlobal FZC'],
#  ['Micromax Informatics', '3One4 Capital', 'scandid'],
#  ['Sandeep Tandon',
#   'remitr',
#   'Pravin Gandhi',
#   'Smart Start Fund; Kunal Shah',
#   'Vishal Gondal',
#   'Vijay Shekhar Sharma',
#   '& Others'],
#  ['Sateesh Andara & others',
#   'Vishal Gondal',
#   'Vijay Shekhar Sharma',
#   'innerchef',
#   'Anupam Mittal',
#   'Phanindra Sama',
#   'M&S Partners',
#   'Mistletoe'],
#  ['Mumbai Angels',
#   'Russian venture capital fund Ru-Net',
#   'Ru-Net',
#   'appsdaily',
#   'Qualcomm Ventures',
#   'Kalaari Capital',
#   'Zodius Capital'],
#  ['muhurtmaza', 'Undisclosed Investor'],
#  ['White Unicorn Ventures', 'azuro', 'Mumbai Angels', 'Kae Capital'],
#  ['Healthsquad', 'neurosynaptic', 'Axilor Ventures', 'Indian Angel Network'],
#  ['Unitus Seed Fund', 'Kiran Mazumdar-Shaw', 'ue lifesciences'],
#  ['Ventureast Fund Advisors', 'findmeashoe'],
#  ['Hyderabad Angels', 'realbox'],
#  ['Sumpoorna Group', 'sportido'],
#  ['gozefo', 'Helion Venture Partners', 'BeeNext'],
#  ['HAX Accelerator', 'rayiot'],
#  ['TCS', 'Elevate Sports', 'kooh sports', 'Faering Capital', 'HDFC'],
#  ['Sanjay Nayar',
#   'Vikram Sud',
#   'Anil Jaggia',
#   'Narayan Seshadri',
#   'flexiloans'],
#  ['Radhakrishnan Natarajan & Others', 'sibia analytics'],
#  ['undisclosed investor', 'vithi.com'],
#  ['Emerald Media', 'yupp tv'],
#  ['Rajesh Arora',
#   'Udaan Angels',
#   'Nitin Passi',
#   'Manickam Mahalingam',
#   'deyor camps',
#   'Arkas Industries'],
#  ['FAO Ventures',
#   'Ranjan Sharma',
#   'India Quotient',
#   'Tushar Singh',
#   'faballey',
#   'Indian Angel Network'],
#  ['shoekonnect', 'Indian Angels Network', 'Indian Angel Network'],
#  ['maya', 'Rajan Anandan'],
#  ['Virendra Patel', 'robovac'],
#  ['newspatrolling', 'Undisclosed'],
#  ['postman', 'Nexus Venture Partners'],
#  ['isfc', 'Gray Matters Capital'],
#  ['Quarizon Consultancy Services LLP', 'beatroute'],
#  ['kidsstoppress', 'Karan Bhagat'],
#  ['Arun Sarin',
#   'dailyhunt',
#   'Falcon Edge',
#   'Sequoia Capital India',
#   'ByteDance',
#   'Omidyar Network',
#   'Matrix Partners'],
#  ['DSG Consumer Partners', 'tazzo bikes'],
#  ['mykindofjob', 'Mayank Shah', 'Shreyans Shah'],
#  ['trilyo', 'Vishnu Bhat', 'Rajiv Lunkad', 'Naresh Ravindranath'],
#  ['Hemant Sahni', 'yumigo'],
#  ['rentalpha', 'Bravia Capital'],
#  ['3dexter', 'Newbie Promoters'],
#  ['babychakra',
#   'Mumbai Angels',
#   'Karan Maheshwari',
#   'RoundGlass Partners',
#   'Roopa Nath',
#   'Singapore Angel Network',
#   'Patni Family Office',
#   'Jatin Aneja',
#   'Kishor Ganji'],
#  ['coppre', 'Ganesh Natarajan'],
#  ['General Catalyst Partners', 'mysun'],
#  ['Hyderabad Angels', 'TLabs', 'epathsala'],
#  ['LightBox Ventures',
#   'furlenco',
#   'Lightbox Ventures and others',
#   'Axis Capital & Others',
#   'Lightbox Ventures'],
#  ['fisdom',
#   'Raghunandan G',
#   'Saama Capital',
#   'Rob Chandra',
#   'Aprameya Radhakrishna'],
#  ['actofit', 'Next Orbit Ventures Fund'],
#  ['Ranjan Pai', 'stayology'],
#  ['hipcask', 'Mobikon'],
#  ['Nandan Nilekani',
#   'Omidyar Networks',
#   'Blume Ventures and Ujama',
#   'railyatri',
#   'Helion Ventures',
#   'Omidiyar Network',
#   'Blume ventures',
#   'Blume Ventures'],
#  ['Janak Jain', 'chatongo'],
#  ['KAE capital', 'wotu'],
#  ['', 'Sequoia Capital', 'Prime Venture Partners', 'kredx'],
#  ['creditmate', 'India Quotient'],
#  ['pickrr', 'Swastika Company Ltd', 'Palaash Ventures'],
#  ['satvakart', 'Nimit Panigrahi'],
#  ['soopermo', 'Lalit Vase'],
#  ['Undisclosed investor', 'orangetwig'],
#  ['hooting Starts Sports LLP', 'Franchise India Brands', 'the kettlery'],
#  ['1Crowd',
#   'idea bubbles',
#   'Shapoorji Pallonji & Co. Ltd.',
#   'Eureka Forbes Ltd'],
#  ['Omnivore Partners', 'fr8'],
#  ['Tiger Global', 'Hero MotoCorp', 'ather energy'],
#  ['Ajay Nanavati', 'Indian Angel Network', 'Afsal Salu', 'pikkol'],
#  ['velmenni', 'Kalaari Capital'],
#  ['Kalaari Capital', 'volta motors'],
#  ['cyclops', 'Kalaari Capital'],
#  ['Aarin Capital', 'Ashish Lakhanpal', 'impact analytics', 'Michael Herzig'],
#  ['talent next', 'Karanpal Singh & Others'],
#  ['',
#   'mad street den',
#   'Sequoia India',
#   'growX ventures',
#   'Exfinity Fund',
#   'Exfinity Ventures',
#   'GrowX Ventures.'],
#  ['mihup', 'Accel Partners'],
#  ['Logtally', 'renowala', 'Pradeep Dhobale'],
#  ['Grasshoppers', 'trackbizz'],
#  ['Yash Dongre', 'Anita Dongre', 'social quotient', 'Milind Sarwate'],
#  ['eshakti', 'Uday Kotak', 'Infina Finance Pvt. Ltd'],
#  ['cheersoye!', 'Undisclosed Investors'],
#  ['Venturra Capital',
#   'Sequoia India',
#   'BEENEXT Ventures',
#   'Kunal Shah & Sandeep Tandon',
#   'Beenext',
#   'Digital Garage',
#   'Beenos',
#   'zilingo',
#   'Susquehanna International Group.\xa0 Wavemaker Partners'],
#  ['Eros Labs', 'alternacare'],
#  ['Brand Capital',
#   'simplilearn',
#   'Mayfield India',
#   'InnoVen Capital India',
#   'Helion Ventures',
#   'Kalaari Capital',
#   'Mayfield Ventures'],
#  ['Earlsfield Capital',
#   'prozo',
#   'Sailender Solanki',
#   'Shomil Pant',
#   'Dinesh Kundu & others',
#   'Rajiv Solanki',
#   'Nalin Jain'],
#  ['CareerNet Consulting Pvt. Ltd',
#   '',
#   'toprankers',
#   'Ideation Initiative Pvt. Ltd'],
#  ['buildtraders', 'Idein Ventures'],
#  ['freshboxx', 'Ravi Linganuri'],
#  ['cureinstant', 'Dr. Rameshwar Kumar'],
#  ['Amit Nagar', 'poshtic', 'havya Sharma'],
#  ['karmacircles',
#   'Abaran Deep',
#   'Zain Raj',
#   'Harinder Takhar',
#   'Dr. Prasad Kaipa',
#   'Aseem Sood',
#   'Mustafa Patni'],
#  ['Roy Kwan',
#   'Rahul Kayan',
#   'Shubham Gupta',
#   'purple style labs',
#   'Augment Ventures',
#   'Nikhil Golcha'],
#  ['inuxu', 'Fork Media'],
#  ['Pradeep Mirani',
#   'Aqeel Ahmed',
#   'Anand Ladsariya',
#   'glam studios',
#   'Nitin Agarwal'],
#  ['Raj Singh Bhandal', 'findow'],
#  ['Ratan Tata', 'ideachakki'],
#  ['nearbuy', 'BlackSoil Capital Pvt. Ltd.'],
#  ['zeroinfy', 'Calcutta Angels Network'],
# ...
#   'Ashish Tulsian',
#   'Vijay Shekhar Sharma',
#   'Binny Bansal',
#   'Blume Ventures',
#   'unaacademy',
#   'Sachin Bansal'],
#  ['Kalaari Capital', 'advenio'],
#  ['Kalaari Capital', 'guarented'],
#  ['Kamal Puri', 'Vineet Taneja', 'beyond evolution'],
#  ['uber dreams', 'Mohit Lalvani'],
#  ['Michael and Susan Dell Foundation', 'convegenius', 'Enablers platform'],
#  ['Trifecta Capital', 'urbanladder'],
#  ['Tracxn Labs', 'encashea', 'Kunal Shah', 'Sandeep Tandon'],
#  ['engineerbabu', 'Scale Ventures'],
#  ['cult', 'CureFit'],
#  ['witworks',
#   'Abhinav Sinha',
#   'Anupam Mittal',
#   'Pranay Jivrajka',
#   'P39 Capital',
#   'Maninder Gulati',
#   'Fireside Ventures',
#   'Investopad'],
#  ['nearfox',
#   'Ravi Jain',
#   'Globevestor Angel Fund',
#   'Arpan Nagdeve',
#   'Devendra Rane'],
#  ['plix', 'Instalabs'],
#  ['Innoven Capital',
#   'GMO Payment Gateway',
#   'Tree Line Asia',
#   'mobikwik',
#   'American Express',
#   'Cisco Investments',
#   'Sequoia Capital',
#   'MediaTek',
#   'Net1 UEPS Technologies Inc'],
#  ['Undisclosed Ex Mckinsey Directors and Partners', 'mydidi'],
#  ['Helion Venture Partners',
#   'Undisclosed investors',
#   'Accel Partners',
#   'Girish Mathrubootham',
#   'crownit',
#   'Kunal Shah & Sandeep Tandon',
#   'Anand Chandrasekaran'],
#  ['Blume Ventures', 'runnr', 'Nexus Venture Partners'],
#  ['zolo', 'Hitouch AG'],
#  ['Undisclosed HNI investors', 'notion press'],
#  ['Jungle Ventures & Bessemer Venture Partners',
#   'Jungle Ventures',
#   'Helion Ventures',
#   'livspace',
#   'Bessemer Venture Partners'],
#  ['Rajasthan Angel Investor Network & Others', 'iaugmentor labs'],
#  ['Rajul Jain',
#   'Badal Malick',
#   'Rishi Gupta & Others',
#   'daybox',
#   'Ashutosh Lawania'],
#  ['Sophia Investment ApS', 'cropin'],
#  ['canvera', 'Info Edge (India) Ltd'],
#  ['prime focus technologies', 'Ambit Pragma'],
#  ['IDG Ventures',
#   'Sandeep Tandon',
#   'Abhishek Jain',
#   'Kunal Bahl',
#   'Zishaan Hayath',
#   'Kunal Shah',
#   'Sequoia Capital',
#   'flyrobe',
#   'Rohit Bansal',
#   'GREE Ventures'],
#  ['inclov', 'Sarbvir Singh', 'Raghav Bahl'],
#  ['Tiger Global Management',
#   'Punit Soni',
#   'MasterCard',
#   'razorpay',
#   'Y Combinator',
#   'Matrix Partners'],
#  ['venture catalysts', 'Zaffiro Ventures'],
#  ['Sequoia Capital',
#   'pressplay tv',
#   'Vistaar Investment Advisors Pvt. Ltd.',
#   'SD Ventures'],
#  ['playment', 'SAIF Partners'],
#  ['wealthtrust', 'India Quotient'],
#  ['Ajeet Khurana & others',
#   'Deepak Gupta',
#   'Powai Lake Ventures',
#   'stitchwood'],
#  ['grab.in', 'Aramex Ventures Llc'],
#  ['fulfil.io', 'Rajan Anandan'],
#  ['IIFL Wealth Management Seed Venture Fund',
#   'Aspada',
#   'Khosla Impact',
#   'neogrowth',
#   'Omidyar Network'],
#  ['seedoc', 'YourNest Angel Fund\xa0 & Others'],
#  ['Accel Partners',
#   'Network 18',
#   'Stripes Group',
#   'bookmyshow',
#   'SAIF Partners'],
#  ['happilyunmarried', 'Info Edge (India) Ltd'],
#  ['don’t scratch your head', 'Zaffiro Ventures', 'Gaurav Singhvi'],
#  ['wedding wishlist', 'Kirthiga Reddy', 'Renuka Ramanath', 'Cherry Tin'],
#  ['',
#   'Zodius Technology Opportunities Fund',
#   'appdaily',
#   'ru-Net',
#   'Qualcomm Ventures',
#   'Kalaari Capital'],
#  ['adytude', 'Indian Angel Network'],
#  ['500 Startups', 'AVG Group', 'Mato Peric & Others', 'quickli'],
#  ['Rothenberg Ventures', 'spectravr'],
#  ['Rahul Garg', 'Alex Chua', 'pitstop', 'Myntra/LivSpace Founders'],
#  ['purplle', 'JSW Ventures', 'Blume Ventures & IvyCap Ventures'],
#  ['Brian Acton', 'trak n tell'],
#  ['Sattva Capital',
#   'JSW Ventures',
#   'Venture Works',
#   'overcart.com',
#   'Omidyar Network'],
#  ['Sequoia Capital', 'sirionlabs'],
#  ['mintm', 'Mumbai Angels', 'Times Internet'],
#  ['Ashish Mahajan', 'hitgrit', 'Sarvesh Sharma'],
#  ['Yogesh Bansal', 'Rishi Parti', 'find my stay'],
#  ['yaap', 'Rainmaker Ventures'],
#  ['Ajay Piramal', 'utoo cabs'],
#  ['Amit Gupta',
#   'Sahil Barua',
#   'Kunal Shah',
#   'twigly',
#   'Gaurav Bhalotia',
#   'Mukul Singhal',
#   'Tracxn Labs',
#   'Hyderabad Angels'],
#  ['urban tailor', 'Unitus Seed Fund', 'Group of angel investors'],
#  ['IDG Ventures India', 'rentmojo', 'Accel Partners'],
#  ['cityfurnish', 'Brand Capital', 'Jitendra Gupta'],
#  ['Jaspal Bindra', 'heal institute', 'Parth Jindal'],
#  ['Keiretsu Forum', 'augrav'],
#  ['Steelhead Ventures & Others', 'Plug and Play Tech Center', 'shoppinpal'],
#  ['transtutors / askiitians', '500 Startups'],
#  ['SRI Capital', 'workapps'],
#  ['undisclosed investors', 'bankerbay'],
#  ['Anurag Gupta', 'Faraz Khan', 'Varun Khanna', 'baggout', 'Sumit Jain'],
#  ['satvacart',
#   'Karan Chellani',
#   'Palaash Ventures',
#   'Undisclosed HNIs',
#   'SP Vijay',
#   'Abhijit Avasthi'],
#  ['Innoven Capital',
#   'Times Internet',
#   'Qualcomm Ventures',
#   'Matrix Partners India',
#   'ridlr'],
#  ['yellowdig', 'SRI Capital'],
#  ['zuppler', 'SRI Capital'],
#  ['Accel Partners',
#   'IIFL and Accel Partners',
#   'Kalaari Capital',
#   'bluestone',
#   'RB Investments',
#   'Dragoneer Investment Group',
#   'IvyCap Ventures'],
#  ['Intelli Reboot Digital Pvt. Ltd', 'underdogs'],
#  ['Satish Jamdar', 'imageprovision'],
#  ['Star India Pvt. Ltd', 'sagacito'],
#  ['deal4loans / wishfin',
#   'Franklin Templeton International Services Pvt. Ltd'],
#  ['Prime Venture Partners', 'niyo solutions'],
#  ['Green House Ventures Accelerator', 'applop', 'GHV Accelerator'],
#  ['tax2win', 'Undisclosed Investors'],
#  ['Shanti Mohan',
#   'Sarath Sura',
#   'Suramya Gupta',
#   'Sarthak and Nihit Agarwal',
#   'truckola',
#   'Abhishek Agarwal',
#   'Krishnakumar Nataraj'],
#  ['iserve financial', 'Nilesh Shah'],
#  ['', 'Nihon Kotsu Co', 'Green House Ventures', 'Nihon Kotsu', 'mytaxiindia'],
#  ['aberuk', 'Swastika Company Pvt Ltd'],
#  ['wiwigo', 'Indian Angel Network'],
#  ['DSG Consumer Partners', 'Verlinvest', 'drums food'],
#  ['chikoop', 'Undisclosed Investors'],
#  ['bridgei2i', 'Edelweiss Private Equity'],
#  ['MapmyIndia', 'visit'],
#  ['Parampara Capital', 'atomberg'],
#  ['coutloot', 'Venture Catalysts'],
#  ['Rainmaker Ventures', 'limo'],
#  ['MadhanKumar Madathupalayam', 'icliniq'],
#  ['gogo truck', 'Undisclosed Investor'],
#  ['Romulus Capital', 'vyome biosciences'],
#  ['sillymonks', 'Sreenivasa Reddy Musani'],
#  ['Yeahmobi', 'Fenqile', 'krazybee'],
#  ['intgrea', 'Undisclosed Investor'],
#  ['Microsoft Ventures', 'helpshift', 'Salesforce Ventures'],
#  ['creditvidya', 'Kalaari Capital'],
#  ['Sarath Sura', 'grey campus'],
#  ['Sandeep Tandon', 'Kunal Shah', 'listup', 'Kae Capital'],
#  ['6degree',
#   'Goa',
#   'Centre For Incubation & Business Acceleration (CIBA)',
#   'Indian Angel Network'],
#  ['Sanjiv Rai', 'shopwati'],
#  ['cookifi',
#   'Krishna Mehra',
#   'Venkat Tadanki',
#   'Aneesh Reddy',
#   'Amit Rathore',
#   'Kunal Shah',
#   'Tracxn Labs'],
#  ['storeking', 'Mangrove Capital Partners', 'Axiata Digital'],
#  ['Ankit Maheshwari', 'Anand Singh', 'wired hub'],
#  ['BlackJag Partners', 'myseniordoctor'],
#  ['Keystone Group',
#   'Accel Partners',
#   'teabox',
#   'JAFCO Asia',
#   'Dragoneer Investment',
#   'Cameron Jones'],
#  ['Ritesh Dwivedy', 'extraaedge', 'Priti Padhy'],
#  ['3 undisclosed HNIs', 'epaylater'],
#  ['Ratan Tata', 'kyazoonga'],
#  ['CIO Angel Network', 'paytunes', 'Indian Angel Network'],
#  ['kickstart jobs',
#   'Vivek Joshi',
#   'Mohit Satyanand',
#   'Amit Banati',
#   'Arun Khanna'],
#  ['freshee', 'Edelweiss Private Equity'],
#  ['Bhavish Aggarwal',
#   'Kunal Bahl',
#   'Girish Mathrubootham',
#   'Ratan Tata',
#   'Binny Bansal',
#   'Rohit Bansal',
#   'Ankit Bhati',
#   'madrat games'],
#  ['jazzmyride', 'TVS Automobile Solutions Ltd'],
#  ['autosense', 'TVS Automobile Solutions Ltd'],
#  ['redsun telematics', 'TVS Automobile Solutions Ltd'],
#  ['50K Ventures', 'khanagadi'],
#  ['undisclosed investor', 'bombay shirt company'],
#  ['Viridian Capital', 'matrubharti'],
#  ['edtechreview', 'EVC Ventures'],
#  ['bonhomia',
#   'Grey Orange Robotics',
#   'Sarvesh Shahra & Others',
#   'Alok Rawat',
#   'Shripad Nadkarni',
#   'Valpro Capital and existing investors',
#   'Kanwaljit Singh'],
#  ['MCube8', 'gobolt'],
#  ['You & Mr Jones', 'Fortisure Ventures', 'Diaz Nesamoney', 'jivox'],
#  ['Blume Ventures & Vaibhav Domkundwar', 'sminq', 'Saama Capital'],
#  ['Venk Krishna',
#   'Larry Braitman',
#   'Accel Partners',
#   'Accel Partners India',
#   'Subrata Mitra',
#   'curejoy'],
#  ['oneway.cab', 'Indian Angel Network'],
#  ['IvyCap Ventures and Unicorn India Ventures', 'grabonrent'],
#  ['unnati helpers', 'Info Edge (India) Ltd'],
#  ['Atul Ingle', 'athletto'],
#  ['Liberty Media',
#   'Tiger Global Management',
#   'Quilvest',
#   'Guy Oseary',
#   'Steadview Capital',
#   'Mousse Partners',
#   'Bertelsmann India',
#   'saavn'],
#  ['Nimmagadda Prasad', 'thinkphi'],
#  ['Max Levchin',
#   'Sequoia Capital',
#   'Ravi Adusumalli',
#   'Scott Banister',
#   'FF Angel',
#   'Paytm (One97 communications)',
#   'cleartax',
#   'SAIF Partners'],
#  ['Infuse Ventures', 'silvan innovation labs'],
#  ['Blume Ventures', 'greythr', 'New Enterprise Associates (NEA)'],
#  ['duffl', 'BetOnIndia Technology Pvt Ltd'],
#  ['Amit Khanna (LetsVenture)', 'Sanjay Verma', 'byg'],
#  ['Undisclosed investor', 'dipper'],
#  ['Hamraj Kumar', 'qonfuse'],
#  ['the indian iris', 'Timbru Ventures'],
#  ['onspoon', 'Swan Angel Network'],
#  ['Idein Ventures', 'restate'],
#  ['Concur Technologies', 'cleartrip', 'Gund Investment'],
#  ['procmart', 'IndiaMart'],
#  ['Bitkemy Ventures', 'celerix'],
#  ['Unicorn Venture', 'naturenama'],
#  ['cyclopsmedtech', 'CP Bothra'],
#  ['syona cosmetics', 'The Chennai Angels', 'Chennai Angels'],
#  ['RB Investments PTE Ltd', 'prettysecrets', 'Orios Venture Partners'],
#  ['Mahendra Doshi',
#   'Adi Saravanan',
#   'Pravin Dongre',
#   'spiderg',
#   'Fusion Tech Ventures',
#   'Rahul Kirloskar'],
#  ['Saif Partners', 'fareye'],
#  ['Purvi Ventures', 'Rajul Garg', 'the uolo', 'Vipin Arora'],
#  ['staqu', 'Indian Angel Network'],
#  ['padhopadhao', 'Rise India'],
#  ['Pankaj Tripathi', 'drivify', 'Jitendra Gupta'],
#  ['Nexus Venture Partners', 'pratilipi'],
#  ['parablu', 'Kalaari Capital'],
#  ['schedulers logistics', 'GVFL'],
#  ['Undisclosed investor', 'kabadiexpress'],
#  ['Aprameya Radhakrishna',
#   'Sanjay Anandaram',
#   'Paula Ravindra Mariwala',
#   'Neeraj Jawalkar',
#   'Aneesh Reddy',
#   'Venk Krishnan',
#   'Vibhu Garg',
#   'Pavan Ongole',
#   'yourdost',
#   'Subba Rao Telidevara',
#   'Gaurav Bhalotia',
#   'Aprameya Radhakrishnan',
#   'Phanindra Sama',
#   'SAIF Partners'],
#  ['Undisclosed investor', 'gomalon'],
#  ['Kanodia family', 'Amit Banka', 'voler cars'],
#  ['RB Investments', 'fabhotels', 'Accel Partners'],
#  ['locanix', 'Undisclosed investors'],
#  ['hello tax', 'Sanjeev Sinha'],
#  ['Soniks Consulting', 'mysuperbrain'],
#  ['blogbeats', 'Undisclosed Investor'],
#  ['vCommission', 'letreach'],
#  ['trendieapp', 'Harsh Vardhan Hada'],
#  ['impactguru', 'Piyush Jain'],
#  ['Uniqorn Ventures Fund', 'TV Mohandas Pai', 'velvetcase', 'S Somasegar'],
#  ['meru cabs', 'Brand Capital', 'Value Fund Advisors'],
#  ['Aarin Capital', 'campus diaries'],
#  ['Accel Partners & existing investors',
#   'Accel Partners',
#   'scripbox',
#   'Rajesh Magow',
#   'Shamik Sharma',
#   'Mohit Gupta',
#   'Deep Kalra',
#   'Omidyar Network'],
#  ['biryani blues', 'Carpediem Capital & Others'],
#  ['', 'motomojo', 'Fauzan Rahim', 'Balamurugan Mani', 'Niloufer Dundh'],
#  ['Ankush Mehta', 'prescribez'],
#  ['airwood', 'StartupXseed Ventures'],
#  ['Vivek Joshi',
#   'Brand Capital',
#   'ah! Ventures',
#   'Mohit Satyanand & others',
#   'idreamcareer'],
#  ['zwayam', 'Undisclosed investors'],
#  ['Varun Ahuja', 'boibanit', 'Anubhav Verma', 'Undisclosed investors'],
#  ['Hermes Group', 'zuver', 'Shruth & Smith Group'],
#  ['Blume Ventures', 'prepathon'],
#  ['Pranav Dedhia',
#   'Rohan Angrish',
#   'easyroads',
#   'Rahul Mehta',
#   'Kapil Hetamsaria',
#   'Hrishi Oberoi'],
#  ['Helion Venture',
#   'Sistema Asia Fund',
#   'VentureEast',
#   'India Alternatives',
#   'seclore'],
#  ['solartown', 'Grex.in'],
#  ['comarete', 'Grex.in'],
#  ['mydentistchoice', 'Undisclosed investors'],
#  ['Kalaari Capital Accelerator Program', 'indee'],
#  ['Group of undisclosed Angel Investors & HNIs', 'weballigator'],
#  ['MoMagic Technologies', 'eduace services'],
#  ['zebroads', 'Undisclosed investors'],
#  ['Rajesh Ranavat',
#   'growX ventures',
#   'BeeNext',
#   'locus',
#   'Exfinity Venture Partners',
#   'Manish Singhal',
#   'Blume Ventures'],
#  ['Vishal Khare', 'toko innovations', 'Roopak Saluja'],
#  ['Sandeep Gupta',
#   'Manish Kheterpal',
#   'Dinesh Mittal',
#   'Vinay Mittal',
#   'rentickle'],
#  ['NanoHoldings', 'innonano research'],
#  ['schoolwear', 'Undisclosed investors'],
#  ['zenify', 'Atul Jalan', 'Undisclosed Investors'],
#  ['faircent',
#   'Kshitij Jain',
#   'JM Financial Products Ltd',
#   'Devesh Sachdev',
#   'Doreswamy Nandkishore',
#   'Ashish Tiwari',
#   'Aarin Capital Partners',
#   'Arun Tadanki'],
#  ['fractal analytics', 'Khazanah Nasional Berhad'],
#  ['GROUPE SOS', 'life circle'],
#  ['Rakesh Gupta',
#   'Siddharth Banerjee',
#   'and Sanjeev Agrawal',
#   'Anshul Jindal',
#   'dream wallets',
#   'Aditya Aggarwal',
#   'Vikas Ranjan',
#   'Sunil Koul'],
#  ['ah! Ventures', 'shabdnagari'],
#  ['', 'Phanindra Sama', 'galleri5', 'Raghunandan G'],
#  ['Anurag Chauhan', 'derbii'],
#  ['stayzilla', 'Nexus Ventures', 'Matrix Partners', 'Nexus Venture Partners'],
#  ['Undisclosed Investors & Tamarind Family Private Trust', 'wow express'],
#  ['smartivity', 'AdvantEdge Partners', 'S Chand'],
#  ['bedbathmore', 'Rocket Internet', 'Kinnevik Group'],
#  ['murgency', 'Axilor Ventures', 'Rata Tata'],
#  ['Anupam Mittal', 'Ankit Nagori', 'blinge', 'Anuj Srivastava'],
#  ['YourNest Angel Fund', 'thesmartq'],
#  ['purplehealth', 'Katabole Technology Venture'],
#  ['fundamentor', 'Subramanya SV'],
#  ['edupristine', 'Kaizen Management Advisors', 'DeVry Inc'],
#  ['Blume Ventures', 'bhiveworkspace'],
#  ['appie', 'Undisclosed investors'],
#  ['taxivaxi', 'Undisclosed HNIs'],
#  ['Chatsworth Management', 'veqta', 'ITW Digital'],
#  ['i2ifunding', 'Undisclosed Investors'],
#  ['vCommission', 'hoppingo'],
#  ['eatonomist', 'MCube Capital Advisors Pvt Ltd'],
#  ['goalwise', 'Undisclosed HNIs'],
#  ['roast', 'Indian Angel Network'],
#  ['Gray Matters Capital', 'address health'],
#  ['Anoop Hingorani', 'arcatron mobility', 'Sudhir Mehta'],
#  ['Anand Mahindra', 'shethepeople'],
#  ['India Innovation Fund India Venture Partners',
#   'Indian Angel Network',
#   'consure medical',
#   'Accel Partners'],
#  ['mchamp', 'MoMagic Technologies'],
#  ['pianta', 'Kunal Shah', 'Sandeep Tandon'],
#  ['Anirudh Damani', 'vahanalytics', 'Vikram Lakhotia'],
#  ['play your sport',
#   'Hyderabad Angels (at Startup Heroes event)',
#   'Ashish Gupta and other undisclosed investors'],
#  ['tpot', 'Ashish Gupta'],
#  ['machadalo', 'Undisclosed Investors'],
#  ['Nelstone Ventures',
#   'dil mil',
#   'Transmedia Capital',
#   'CSC Upshot & Angel investors',
#   'Maiden Lane Ventures'],
#  ['picsdream', 'Raman Roy'],
#  ['Kris Gopalakrishnan',
#   'Ajai Chowdhry',
#   'Alok Sharma',
#   'and Ajai Chowdhry',
#   'process 9',
#   'IAN Ventures',
#   'Saurabh Srivastava',
#   'Indian Angel Network'],
#  ['Vineet Singh', 'housing'],
#  ['Equentia Natural Resource & Other undisclosed investors', 'roll mafia'],
#  ['Xiaomi Inc', 'hungama'],
#  ['highway delite', 'N.S. Raghavan Centre for Entrepreneurial Learning'],
#  ['cult fitness', 'Mukesh Bansal'],
#  ['Times Internet Ltd', 'haptik'],
#  ['shipsy', 'DTDC Express Ltd'],
#  ['gear6', 'Ninestarter'],
#  ['truly social', 'Nazara Technologies Pvt Ltd'],
#  ['little black book', 'Indian Angel Network', 'IDG'],
#  ['vahan', 'Villgro'],
#  ['Mahendra Patel', 'Nilender Chauhan', 'imedilane'],
#  ['living local', 'Rattan Chadha'],
#  ['vegfru', 'Wingify'],
#  ['priceraja', 'Prashant Puri'],
#  ['Dr. Ranjan Pai', 'Kris Gopalakrishnan', 'magicx'],
#  ['happydemic', 'Shaan'],
#  ['Narendra Karnavat',
#   'Jayesh Shah',
#   'Vikas Kapoor',
#   'Anirudh Damani',
#   'Vikram Lakhotia',
#   'Krishna Jhunjhunwaala',
#   'lendenclub',
#   'Daud Ali'],
#  ['indi.com', 'Anil Kapoor'],
#  ['Yatin Kumar Jain', 'legalraasta', 'Pravin Khandelwal'],
#  ['raincan', 'Dr. Aniruddha Malpani', 'Ajeet Khurana & Others'],
#  ['hippily', 'Rakesh Mathur', 'Dr. Sridhar Ramaswamy'],
#  ['StartUp Equity Partners', 'wedwise'],
#  ['Puneet Bhatia & others', 'Rajeev Agrawal', 'Prashant Gooty', 'beaconstalk'],
#  ['Puru Vashishtha', 'deal 4loans', 'Neeraj Arora', 'Ram Shriram'],
#  ['Mount Nathan Advisors Pte Ltd', 'renewbuy', 'Mount Nathan Advisors'],
#  ['Kamal Kothari',
#   'Sanjay Phophaliya',
#   'Siddharth Agarwal',
#   'Yogesh Chaudhary',
#   'Mahavir Pratap Sharma',
#   'blue box media',
#   'Ajay Data'],
#  ...]

# %% [markdown]
# ## Converting list of list into Dictionary

# %%
d = {}
for i in range(len(l)):
    for j in range(len(l[i])):
        temp = l[i][j]
        d[temp] = d.get(temp,0)+1

# %%
t = {} # taking another dictionary havng no null values from dictionary d
for i in d:
    if(i !=''):  # removing null string 
        t[i]=d[i]

# %% [markdown]
# ##  getting top 5 unique investors

# %%
from collections import Counter
dic = dict(Counter(t).most_common(5))
x = [] 
y= []
for i in dic:
    x.append(i) #Getting keys from dictionary
    y.append(dic[i])# Getting Freq of the values
    print(i,dic[i])
# Out:
# Accel Partners 46
# Sequoia Capital 46
# Indian Angel Network 40
# Kalaari Capital 39
# Blume Ventures 36

# %% [markdown]
# # Graph of Unique Investor v/s the no. of times they invested

# %%
plt.bar(x,y,edgecolor ='black',width=0.5)
plt.xlabel('Top 5 Unique Investors Who have invested in Startup')
plt.ylabel('Frequency of each Investor')
plt.xticks(rotation =45)
plt.title('Investor v/s Frequency')
plt.show()
